# %% [markdown]
# # Group 3 Runs without std consideration

# %%
from GA_optimiser import *
import os

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]
I_type = ['v','a']
lookback_params = [9,20,30,50,100,150,200]
scaling_factor_params = [1,5,0.5]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])
n_I_type_params = len(I_type)
n_lookback_params = len(lookback_params)
n_scaling_factor_params = ((scaling_factor_params[1]-scaling_factor_params[0])/scaling_factor_params[2])
print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('number of I_type params:-',(n_I_type_params))
print('number of lookback params:-',(n_lookback_params))
print('number of scaling_factor params:-',(n_scaling_factor_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params*n_I_type_params*n_lookback_params*n_scaling_factor_params))

parameters = [grid_params,lot_params,I_type,lookback_params,scaling_factor_params]

# Adjust these parameter according to search space
n_trials = 50 #NGEN
npop = 100
early_stopping_gen = n_trials # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# number of I_type params:- 2
# number of lookback params:- 7
# number of scaling_factor params:- 8.0
# total_number_of_combinations:- 38304.0

# %%
gen_results('jan 2014','jan 2022',12,1,currency_pair='EURGBP',parameters=parameters,optimizer_param=optimizer_param)
gen_results('jan 2014','jan 2022',6,1,currency_pair='EURGBP',parameters=parameters,optimizer_param=optimizer_param)
gen_results('jan 2014','jan 2022',3,1,currency_pair='EURGBP',parameters=parameters,optimizer_param=optimizer_param)
# Out:
# Data gathered for training period:  01 Jan 2013 31 Dec 2013
# Data gathered for testing period:  01 Jan 2014 31 Jan 2014
# optimisation completed
# Optimal parameters are:  [0.0065, 1400000, 'a', 200, 5.0]
# Data gathered for training period:  01 Feb 2013 31 Jan 2014
# Data gathered for testing period:  01 Feb 2014 28 Feb 2014
# optimisation completed
# Optimal parameters are:  [0.006, 1200000, 'a', 20, 3.0]
# Data gathered for training period:  01 Mar 2013 28 Feb 2014
# Data gathered for testing period:  01 Mar 2014 31 Mar 2014
# optimisation completed
# Optimal parameters are:  [0.009, 2000000, 'a', 9, 5.0]
# Data gathered for training period:  01 Apr 2013 31 Mar 2014
# Data gathered for testing period:  01 Apr 2014 30 Apr 2014
# optimisation completed
# Optimal parameters are:  [0.009, 1600000, 'v', 150, 4.0]
# Data gathered for training period:  01 May 2013 30 Apr 2014
# Data gathered for testing period:  01 May 2014 31 May 2014
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'a', 20, 3.5]
# Data gathered for training period:  01 Jun 2013 31 May 2014
# Data gathered for testing period:  01 Jun 2014 30 Jun 2014
# optimisation completed
# Optimal parameters are:  [0.008, 2000000, 'a', 30, 4.5]
# Data gathered for training period:  01 Jul 2013 30 Jun 2014
# Data gathered for testing period:  01 Jul 2014 31 Jul 2014
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000, 'v', 150, 2.0]
# Data gathered for training period:  01 Aug 2013 31 Jul 2014
# Data gathered for testing period:  01 Aug 2014 31 Aug 2014
# optimisation completed
# Optimal parameters are:  [0.007, 1800000, 'v', 200, 1.0]
# Data gathered for training period:  01 Sep 2013 31 Aug 2014
# Data gathered for testing period:  01 Sep 2014 30 Sep 2014
# optimisation completed
# Optimal parameters are:  [0.0075, 600000, 'a', 20, 4.5]
# Data gathered for training period:  01 Oct 2013 30 Sep 2014
# Data gathered for testing period:  01 Oct 2014 31 Oct 2014
# optimisation completed
# Optimal parameters are:  [0.007, 1700000, 'a', 20, 5.0]
# Data gathered for training period:  01 Nov 2013 31 Oct 2014
# Data gathered for testing period:  01 Nov 2014 30 Nov 2014
# optimisation completed
# Optimal parameters are:  [0.0035, 1000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Dec 2013 30 Nov 2014
# Data gathered for testing period:  01 Dec 2014 31 Dec 2014
# optimisation completed
# Optimal parameters are:  [0.0035, 900000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jan 2014 31 Dec 2014
# Data gathered for testing period:  01 Jan 2015 31 Jan 2015
# optimisation completed
# Optimal parameters are:  [0.002, 300000, 'v', 30, 5.0]
# Data gathered for training period:  01 Feb 2014 31 Jan 2015
# Data gathered for testing period:  01 Feb 2015 28 Feb 2015
# optimisation completed
# Optimal parameters are:  [0.0015, 400000, 'v', 50, 5.0]
# Data gathered for training period:  01 Mar 2014 28 Feb 2015
# Data gathered for testing period:  01 Mar 2015 31 Mar 2015
# optimisation completed
# Optimal parameters are:  [0.0015, 200000, 'v', 30, 5.0]
# Data gathered for training period:  01 Apr 2014 31 Mar 2015
# Data gathered for testing period:  01 Apr 2015 30 Apr 2015
# optimisation completed
# Optimal parameters are:  [0.0015, 200000, 'v', 30, 5.0]
# Data gathered for training period:  01 May 2014 30 Apr 2015
# Data gathered for testing period:  01 May 2015 31 May 2015
# optimisation completed
# Optimal parameters are:  [0.002, 200000, 'v', 20, 5.0]
# Data gathered for training period:  01 Jun 2014 31 May 2015
# Data gathered for testing period:  01 Jun 2015 30 Jun 2015
# optimisation completed
# Optimal parameters are:  [0.0065, 600000, 'v', 150, 5.0]
# Data gathered for training period:  01 Jul 2014 30 Jun 2015
# Data gathered for testing period:  01 Jul 2015 31 Jul 2015
# optimisation completed
# Optimal parameters are:  [0.0015, 100000, 'v', 50, 5.0]
# Data gathered for training period:  01 Aug 2014 31 Jul 2015
# Data gathered for testing period:  01 Aug 2015 31 Aug 2015
# optimisation completed
# Optimal parameters are:  [0.0095, 1100000, 'v', 200, 4.5]
# Data gathered for training period:  01 Sep 2014 31 Aug 2015
# Data gathered for testing period:  01 Sep 2015 30 Sep 2015
# optimisation completed
# Optimal parameters are:  [0.006, 1600000, 'v', 200, 4.5]
# Data gathered for training period:  01 Oct 2014 30 Sep 2015
# Data gathered for testing period:  01 Oct 2015 31 Oct 2015
# optimisation completed
# Optimal parameters are:  [0.008, 1600000, 'a', 9, 2.5]
# Data gathered for training period:  01 Nov 2014 31 Oct 2015
# Data gathered for testing period:  01 Nov 2015 30 Nov 2015
# optimisation completed
# Optimal parameters are:  [0.0065, 1700000, 'a', 9, 1.0]
# Data gathered for training period:  01 Dec 2014 30 Nov 2015
# Data gathered for testing period:  01 Dec 2015 31 Dec 2015
# optimisation completed
# Optimal parameters are:  [0.0095, 1700000, 'v', 150, 1.5]
# Data gathered for training period:  01 Jan 2015 31 Dec 2015
# Data gathered for testing period:  01 Jan 2016 31 Jan 2016
# optimisation completed
# Optimal parameters are:  [0.006, 1500000, 'a', 9, 3.5]
# Data gathered for training period:  01 Feb 2015 31 Jan 2016
# Data gathered for testing period:  01 Feb 2016 29 Feb 2016
# optimisation completed
# Optimal parameters are:  [0.008, 1800000, 'a', 100, 5.0]
# Data gathered for training period:  01 Mar 2015 29 Feb 2016
# Data gathered for testing period:  01 Mar 2016 31 Mar 2016
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'a', 100, 2.0]
# Data gathered for training period:  01 Apr 2015 31 Mar 2016
# Data gathered for testing period:  01 Apr 2016 30 Apr 2016
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000, 'a', 150, 4.0]
# Data gathered for training period:  01 May 2015 30 Apr 2016
# Data gathered for testing period:  01 May 2016 31 May 2016
# optimisation completed
# Optimal parameters are:  [0.006, 1700000, 'a', 20, 5.0]
# Data gathered for training period:  01 Jun 2015 31 May 2016
# Data gathered for testing period:  01 Jun 2016 30 Jun 2016
# optimisation completed
# Optimal parameters are:  [0.0075, 1300000, 'a', 20, 2.0]
# Data gathered for training period:  01 Jul 2015 30 Jun 2016
# Data gathered for testing period:  01 Jul 2016 31 Jul 2016
# optimisation completed
# Optimal parameters are:  [0.0075, 2000000, 'a', 50, 5.0]
# Data gathered for training period:  01 Aug 2015 31 Jul 2016
# Data gathered for testing period:  01 Aug 2016 31 Aug 2016
# optimisation completed
# Optimal parameters are:  [0.0065, 1500000, 'a', 30, 4.0]
# Data gathered for training period:  01 Sep 2015 31 Aug 2016
# Data gathered for testing period:  01 Sep 2016 30 Sep 2016
# optimisation completed
# Optimal parameters are:  [0.0075, 1900000, 'a', 9, 4.5]
# Data gathered for training period:  01 Oct 2015 30 Sep 2016
# Data gathered for testing period:  01 Oct 2016 31 Oct 2016
# optimisation completed
# Optimal parameters are:  [0.0065, 1600000, 'a', 9, 5.0]
# Data gathered for training period:  01 Nov 2015 31 Oct 2016
# Data gathered for testing period:  01 Nov 2016 30 Nov 2016
# optimisation completed
# Optimal parameters are:  [0.007, 1700000, 'a', 9, 4.0]
# Data gathered for training period:  01 Dec 2015 30 Nov 2016
# Data gathered for testing period:  01 Dec 2016 31 Dec 2016
# optimisation completed
# Optimal parameters are:  [0.006, 1900000, 'v', 200, 3.0]
# Data gathered for training period:  01 Jan 2016 31 Dec 2016
# Data gathered for testing period:  01 Jan 2017 31 Jan 2017
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'a', 9, 5.0]
# Data gathered for training period:  01 Feb 2016 31 Jan 2017
# Data gathered for testing period:  01 Feb 2017 28 Feb 2017
# optimisation completed
# Optimal parameters are:  [0.0065, 1500000, 'a', 50, 3.0]
# Data gathered for training period:  01 Mar 2016 28 Feb 2017
# Data gathered for testing period:  01 Mar 2017 31 Mar 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 200, 1.5]
# Data gathered for training period:  01 Apr 2016 31 Mar 2017
# Data gathered for testing period:  01 Apr 2017 30 Apr 2017
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000, 'a', 9, 5.0]
# Data gathered for training period:  01 May 2016 30 Apr 2017
# Data gathered for testing period:  01 May 2017 31 May 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 200, 1.0]
# Data gathered for training period:  01 Jun 2016 31 May 2017
# Data gathered for testing period:  01 Jun 2017 30 Jun 2017
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000, 'a', 30, 4.0]
# Data gathered for training period:  01 Jul 2016 30 Jun 2017
# Data gathered for testing period:  01 Jul 2017 31 Jul 2017
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000, 'a', 200, 4.0]
# Data gathered for training period:  01 Aug 2016 31 Jul 2017
# Data gathered for testing period:  01 Aug 2017 31 Aug 2017
# optimisation completed
# Optimal parameters are:  [0.0075, 1800000, 'v', 20, 4.0]
# Data gathered for training period:  01 Sep 2016 31 Aug 2017
# Data gathered for testing period:  01 Sep 2017 30 Sep 2017
# optimisation completed
# Optimal parameters are:  [0.007, 1300000, 'v', 20, 5.0]
# Data gathered for training period:  01 Oct 2016 30 Sep 2017
# Data gathered for testing period:  01 Oct 2017 31 Oct 2017
# optimisation completed
# Optimal parameters are:  [0.008, 1800000, 'v', 20, 5.0]
# Data gathered for training period:  01 Nov 2016 31 Oct 2017
# Data gathered for testing period:  01 Nov 2017 30 Nov 2017
# optimisation completed
# Optimal parameters are:  [0.007, 1500000, 'v', 20, 4.0]
# Data gathered for training period:  01 Dec 2016 30 Nov 2017
# Data gathered for testing period:  01 Dec 2017 31 Dec 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 1300000, 'v', 9, 3.5]
# Data gathered for training period:  01 Jan 2017 31 Dec 2017
# Data gathered for testing period:  01 Jan 2018 31 Jan 2018
# optimisation completed
# Optimal parameters are:  [0.007, 1900000, 'v', 30, 5.0]
# Data gathered for training period:  01 Feb 2017 31 Jan 2018
# Data gathered for testing period:  01 Feb 2018 28 Feb 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 1000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Mar 2017 28 Feb 2018
# Data gathered for testing period:  01 Mar 2018 31 Mar 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1400000, 'v', 9, 4.0]
# Data gathered for training period:  01 Apr 2017 31 Mar 2018
# Data gathered for testing period:  01 Apr 2018 30 Apr 2018
# optimisation completed
# Optimal parameters are:  [0.0035, 500000, 'v', 30, 5.0]
# Data gathered for training period:  01 May 2017 30 Apr 2018
# Data gathered for testing period:  01 May 2018 31 May 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 1300000, 'v', 30, 5.0]
# Data gathered for training period:  01 Jun 2017 31 May 2018
# Data gathered for testing period:  01 Jun 2018 30 Jun 2018
# optimisation completed
# Optimal parameters are:  [0.006, 1900000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jul 2017 30 Jun 2018
# Data gathered for testing period:  01 Jul 2018 31 Jul 2018
# optimisation completed
# Optimal parameters are:  [0.007, 1800000, 'a', 9, 2.5]
# Data gathered for training period:  01 Aug 2017 31 Jul 2018
# Data gathered for testing period:  01 Aug 2018 31 Aug 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'a', 100, 4.5]
# Data gathered for training period:  01 Sep 2017 31 Aug 2018
# Data gathered for testing period:  01 Sep 2018 30 Sep 2018
# optimisation completed
# Optimal parameters are:  [0.01, 1100000, 'a', 9, 5.0]
# Data gathered for training period:  01 Oct 2017 30 Sep 2018
# Data gathered for testing period:  01 Oct 2018 31 Oct 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000, 'v', 9, 2.0]
# Data gathered for training period:  01 Nov 2017 31 Oct 2018
# Data gathered for testing period:  01 Nov 2018 30 Nov 2018
# optimisation completed
# Optimal parameters are:  [0.007, 1900000, 'v', 9, 3.5]
# Data gathered for training period:  01 Dec 2017 30 Nov 2018
# Data gathered for testing period:  01 Dec 2018 31 Dec 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 30, 2.5]
# Data gathered for training period:  01 Jan 2018 31 Dec 2018
# Data gathered for testing period:  01 Jan 2019 31 Jan 2019
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 30, 1.0]
# Data gathered for training period:  01 Feb 2018 31 Jan 2019
# Data gathered for testing period:  01 Feb 2019 28 Feb 2019
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 50, 2.0]
# Data gathered for training period:  01 Mar 2018 28 Feb 2019
# Data gathered for testing period:  01 Mar 2019 31 Mar 2019
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'v', 20, 1.5]
# Data gathered for training period:  01 Apr 2018 31 Mar 2019
# Data gathered for testing period:  01 Apr 2019 30 Apr 2019
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 150, 2.5]
# Data gathered for training period:  01 May 2018 30 Apr 2019
# Data gathered for testing period:  01 May 2019 31 May 2019
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000, 'v', 150, 3.0]
# Data gathered for training period:  01 Jun 2018 31 May 2019
# Data gathered for testing period:  01 Jun 2019 30 Jun 2019
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000, 'v', 200, 3.5]
# Data gathered for training period:  01 Jul 2018 30 Jun 2019
# Data gathered for testing period:  01 Jul 2019 31 Jul 2019
# optimisation completed
# Optimal parameters are:  [0.002, 1700000, 'a', 30, 4.5]
# Data gathered for training period:  01 Aug 2018 31 Jul 2019
# Data gathered for testing period:  01 Aug 2019 31 Aug 2019
# optimisation completed
# Optimal parameters are:  [0.0045, 1800000, 'v', 50, 1.5]
# Data gathered for training period:  01 Sep 2018 31 Aug 2019
# Data gathered for testing period:  01 Sep 2019 30 Sep 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1000000, 'a', 50, 4.5]
# Data gathered for training period:  01 Oct 2018 30 Sep 2019
# Data gathered for testing period:  01 Oct 2019 31 Oct 2019
# optimisation completed
# Optimal parameters are:  [0.002, 1100000, 'a', 9, 4.5]
# Data gathered for training period:  01 Nov 2018 31 Oct 2019
# Data gathered for testing period:  01 Nov 2019 30 Nov 2019
# optimisation completed
# Optimal parameters are:  [0.0025, 1700000, 'a', 9, 3.5]
# Data gathered for training period:  01 Dec 2018 30 Nov 2019
# Data gathered for testing period:  01 Dec 2019 31 Dec 2019
# optimisation completed
# Optimal parameters are:  [0.0025, 1700000, 'a', 20, 4.0]
# Data gathered for training period:  01 Jan 2019 31 Dec 2019
# Data gathered for testing period:  01 Jan 2020 31 Jan 2020
# optimisation completed
# Optimal parameters are:  [0.0025, 1700000, 'a', 20, 4.5]
# Data gathered for training period:  01 Feb 2019 31 Jan 2020
# Data gathered for testing period:  01 Feb 2020 29 Feb 2020
# optimisation completed
# Optimal parameters are:  [0.0025, 1900000, 'a', 100, 3.0]
# Data gathered for training period:  01 Mar 2019 29 Feb 2020
# Data gathered for testing period:  01 Mar 2020 31 Mar 2020
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 200, 2.5]
# Data gathered for training period:  01 Apr 2019 31 Mar 2020
# Data gathered for testing period:  01 Apr 2020 30 Apr 2020
# optimisation completed
# Optimal parameters are:  [0.009, 2000000, 'a', 100, 4.5]
# Data gathered for training period:  01 May 2019 30 Apr 2020
# Data gathered for testing period:  01 May 2020 31 May 2020
# optimisation completed
# Optimal parameters are:  [0.0085, 1900000, 'a', 150, 5.0]
# Data gathered for training period:  01 Jun 2019 31 May 2020
# Data gathered for testing period:  01 Jun 2020 30 Jun 2020
# optimisation completed
# Optimal parameters are:  [0.0075, 1600000, 'a', 100, 2.5]
# Data gathered for training period:  01 Jul 2019 30 Jun 2020
# Data gathered for testing period:  01 Jul 2020 31 Jul 2020
# optimisation completed
# Optimal parameters are:  [0.002, 1400000, 'v', 20, 4.0]
# Data gathered for training period:  01 Aug 2019 31 Jul 2020
# Data gathered for testing period:  01 Aug 2020 31 Aug 2020
# optimisation completed
# Optimal parameters are:  [0.0085, 1900000, 'a', 200, 2.0]
# Data gathered for training period:  01 Sep 2019 31 Aug 2020
# Data gathered for testing period:  01 Sep 2020 30 Sep 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 1300000, 'v', 100, 4.5]
# Data gathered for training period:  01 Oct 2019 30 Sep 2020
# Data gathered for testing period:  01 Oct 2020 31 Oct 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 1400000, 'v', 100, 5.0]
# Data gathered for training period:  01 Nov 2019 31 Oct 2020
# Data gathered for testing period:  01 Nov 2020 30 Nov 2020
# optimisation completed
# Optimal parameters are:  [0.006, 1200000, 'a', 100, 2.5]
# Data gathered for training period:  01 Dec 2019 30 Nov 2020
# Data gathered for testing period:  01 Dec 2020 31 Dec 2020
# optimisation completed
# Optimal parameters are:  [0.0045, 2000000, 'a', 30, 1.0]
# Data gathered for training period:  01 Jan 2020 31 Dec 2020
# Data gathered for testing period:  01 Jan 2021 31 Jan 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1300000, 'v', 100, 5.0]
# Data gathered for training period:  01 Feb 2020 31 Jan 2021
# Data gathered for testing period:  01 Feb 2021 28 Feb 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1500000, 'v', 100, 5.0]
# Data gathered for training period:  01 Mar 2020 28 Feb 2021
# Data gathered for testing period:  01 Mar 2021 31 Mar 2021
# optimisation completed
# Optimal parameters are:  [0.0045, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Apr 2020 31 Mar 2021
# Data gathered for testing period:  01 Apr 2021 30 Apr 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1500000, 'v', 100, 5.0]
# Data gathered for training period:  01 May 2020 30 Apr 2021
# Data gathered for testing period:  01 May 2021 31 May 2021
# optimisation completed
# Optimal parameters are:  [0.0035, 1900000, 'v', 9, 4.5]
# Data gathered for training period:  01 Jun 2020 31 May 2021
# Data gathered for testing period:  01 Jun 2021 30 Jun 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1500000, 'v', 150, 4.5]
# Data gathered for training period:  01 Jul 2020 30 Jun 2021
# Data gathered for testing period:  01 Jul 2021 31 Jul 2021
# optimisation completed
# Optimal parameters are:  [0.0065, 1700000, 'v', 200, 2.0]
# Data gathered for training period:  01 Aug 2020 31 Jul 2021
# Data gathered for testing period:  01 Aug 2021 31 Aug 2021
# optimisation completed
# Optimal parameters are:  [0.0065, 1800000, 'a', 9, 3.5]
# Data gathered for training period:  01 Sep 2020 31 Aug 2021
# Data gathered for testing period:  01 Sep 2021 30 Sep 2021
# optimisation completed
# Optimal parameters are:  [0.0065, 1800000, 'a', 150, 4.5]
# Data gathered for training period:  01 Oct 2020 30 Sep 2021
# Data gathered for testing period:  01 Oct 2021 31 Oct 2021
# optimisation completed
# Optimal parameters are:  [0.0095, 1400000, 'a', 50, 3.5]
# Data gathered for training period:  01 Nov 2020 31 Oct 2021
# Data gathered for testing period:  01 Nov 2021 30 Nov 2021
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Dec 2020 30 Nov 2021
# Data gathered for testing period:  01 Dec 2021 31 Dec 2021
# optimisation completed
# Optimal parameters are:  [0.008, 1300000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jul 2013 31 Dec 2013
# Data gathered for testing period:  01 Jan 2014 31 Jan 2014
# optimisation completed
# Optimal parameters are:  [0.0085, 1800000, 'v', 50, 4.5]
# Data gathered for training period:  01 Aug 2013 31 Jan 2014
# Data gathered for testing period:  01 Feb 2014 28 Feb 2014
# optimisation completed
# Optimal parameters are:  [0.009, 1900000, 'a', 9, 5.0]
# Data gathered for training period:  01 Sep 2013 28 Feb 2014
# Data gathered for testing period:  01 Mar 2014 31 Mar 2014
# optimisation completed
# Optimal parameters are:  [0.007, 1900000, 'a', 100, 1.5]
# Data gathered for training period:  01 Oct 2013 31 Mar 2014
# Data gathered for testing period:  01 Apr 2014 30 Apr 2014
# optimisation completed
# Optimal parameters are:  [0.009, 1900000, 'a', 20, 5.0]
# Data gathered for training period:  01 Nov 2013 30 Apr 2014
# Data gathered for testing period:  01 May 2014 31 May 2014
# optimisation completed
# Optimal parameters are:  [0.0045, 1700000, 'a', 100, 1.0]
# Data gathered for training period:  01 Dec 2013 31 May 2014
# Data gathered for testing period:  01 Jun 2014 30 Jun 2014
# optimisation completed
# Optimal parameters are:  [0.0055, 1800000, 'a', 9, 4.5]
# Data gathered for training period:  01 Jan 2014 30 Jun 2014
# Data gathered for testing period:  01 Jul 2014 31 Jul 2014
# optimisation completed
# Optimal parameters are:  [0.007, 1800000, 'a', 9, 3.0]
# Data gathered for training period:  01 Feb 2014 31 Jul 2014
# Data gathered for testing period:  01 Aug 2014 31 Aug 2014
# optimisation completed
# Optimal parameters are:  [0.004, 1800000, 'v', 20, 5.0]
# Data gathered for training period:  01 Mar 2014 31 Aug 2014
# Data gathered for testing period:  01 Sep 2014 30 Sep 2014
# optimisation completed
# Optimal parameters are:  [0.0045, 1300000, 'v', 20, 5.0]
# Data gathered for training period:  01 Apr 2014 30 Sep 2014
# Data gathered for testing period:  01 Oct 2014 31 Oct 2014
# optimisation completed
# Optimal parameters are:  [0.002, 700000, 'v', 20, 4.5]
# Data gathered for training period:  01 May 2014 31 Oct 2014
# Data gathered for testing period:  01 Nov 2014 30 Nov 2014
# optimisation completed
# Optimal parameters are:  [0.0035, 1200000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jun 2014 30 Nov 2014
# Data gathered for testing period:  01 Dec 2014 31 Dec 2014
# optimisation completed
# Optimal parameters are:  [0.004, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jul 2014 31 Dec 2014
# Data gathered for testing period:  01 Jan 2015 31 Jan 2015
# optimisation completed
# Optimal parameters are:  [0.002, 300000, 'v', 30, 5.0]
# Data gathered for training period:  01 Aug 2014 31 Jan 2015
# Data gathered for testing period:  01 Feb 2015 28 Feb 2015
# optimisation completed
# Optimal parameters are:  [0.002, 300000, 'v', 20, 5.0]
# Data gathered for training period:  01 Sep 2014 28 Feb 2015
# Data gathered for testing period:  01 Mar 2015 31 Mar 2015
# optimisation completed
# Optimal parameters are:  [0.001, 100000, 'v', 200, 5.0]
# Data gathered for training period:  01 Oct 2014 31 Mar 2015
# Data gathered for testing period:  01 Apr 2015 30 Apr 2015
# optimisation completed
# Optimal parameters are:  [0.0015, 200000, 'v', 30, 5.0]
# Data gathered for training period:  01 Nov 2014 30 Apr 2015
# Data gathered for testing period:  01 May 2015 31 May 2015
# optimisation completed
# Optimal parameters are:  [0.0015, 900000, 'v', 30, 4.5]
# Data gathered for training period:  01 Dec 2014 31 May 2015
# Data gathered for testing period:  01 Jun 2015 30 Jun 2015
# optimisation completed
# Optimal parameters are:  [0.0015, 800000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jan 2015 30 Jun 2015
# Data gathered for testing period:  01 Jul 2015 31 Jul 2015
# optimisation completed
# Optimal parameters are:  [0.0095, 1900000, 'a', 9, 5.0]
# Data gathered for training period:  01 Feb 2015 31 Jul 2015
# Data gathered for testing period:  01 Aug 2015 31 Aug 2015
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'a', 100, 2.0]
# Data gathered for training period:  01 Mar 2015 31 Aug 2015
# Data gathered for testing period:  01 Sep 2015 30 Sep 2015
# optimisation completed
# Optimal parameters are:  [0.0075, 1800000, 'a', 9, 5.0]
# Data gathered for training period:  01 Apr 2015 30 Sep 2015
# Data gathered for testing period:  01 Oct 2015 31 Oct 2015
# optimisation completed
# Optimal parameters are:  [0.0055, 1700000, 'a', 200, 3.5]
# Data gathered for training period:  01 May 2015 31 Oct 2015
# Data gathered for testing period:  01 Nov 2015 30 Nov 2015
# optimisation completed
# Optimal parameters are:  [0.0045, 700000, 'a', 9, 4.5]
# Data gathered for training period:  01 Jun 2015 30 Nov 2015
# Data gathered for testing period:  01 Dec 2015 31 Dec 2015
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'a', 100, 1.0]
# Data gathered for training period:  01 Jul 2015 31 Dec 2015
# Data gathered for testing period:  01 Jan 2016 31 Jan 2016
# optimisation completed
# Optimal parameters are:  [0.006, 2000000, 'a', 150, 3.0]
# Data gathered for training period:  01 Aug 2015 31 Jan 2016
# Data gathered for testing period:  01 Feb 2016 29 Feb 2016
# optimisation completed
# Optimal parameters are:  [0.0075, 1800000, 'a', 30, 4.5]
# Data gathered for training period:  01 Sep 2015 29 Feb 2016
# Data gathered for testing period:  01 Mar 2016 31 Mar 2016
# optimisation completed
# Optimal parameters are:  [0.0085, 1700000, 'a', 9, 2.0]
# Data gathered for training period:  01 Oct 2015 31 Mar 2016
# Data gathered for testing period:  01 Apr 2016 30 Apr 2016
# optimisation completed
# Optimal parameters are:  [0.0095, 1500000, 'a', 50, 5.0]
# Data gathered for training period:  01 Nov 2015 30 Apr 2016
# Data gathered for testing period:  01 May 2016 31 May 2016
# optimisation completed
# Optimal parameters are:  [0.006, 1800000, 'v', 100, 2.0]
# Data gathered for training period:  01 Dec 2015 31 May 2016
# Data gathered for testing period:  01 Jun 2016 30 Jun 2016
# optimisation completed
# Optimal parameters are:  [0.008, 1900000, 'v', 200, 3.5]
# Data gathered for training period:  01 Jan 2016 30 Jun 2016
# Data gathered for testing period:  01 Jul 2016 31 Jul 2016
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'a', 20, 5.0]
# Data gathered for training period:  01 Feb 2016 31 Jul 2016
# Data gathered for testing period:  01 Aug 2016 31 Aug 2016
# optimisation completed
# Optimal parameters are:  [0.007, 1900000, 'a', 50, 4.0]
# Data gathered for training period:  01 Mar 2016 31 Aug 2016
# Data gathered for testing period:  01 Sep 2016 30 Sep 2016
# optimisation completed
# Optimal parameters are:  [0.006, 1400000, 'a', 9, 5.0]
# Data gathered for training period:  01 Apr 2016 30 Sep 2016
# Data gathered for testing period:  01 Oct 2016 31 Oct 2016
# optimisation completed
# Optimal parameters are:  [0.0025, 1200000, 'a', 20, 3.5]
# Data gathered for training period:  01 May 2016 31 Oct 2016
# Data gathered for testing period:  01 Nov 2016 30 Nov 2016
# optimisation completed
# Optimal parameters are:  [0.005, 2000000, 'a', 150, 3.5]
# Data gathered for training period:  01 Jun 2016 30 Nov 2016
# Data gathered for testing period:  01 Dec 2016 31 Dec 2016
# optimisation completed
# Optimal parameters are:  [0.0045, 1700000, 'a', 9, 1.5]
# Data gathered for training period:  01 Jul 2016 31 Dec 2016
# Data gathered for testing period:  01 Jan 2017 31 Jan 2017
# optimisation completed
# Optimal parameters are:  [0.003, 1200000, 'a', 150, 3.5]
# Data gathered for training period:  01 Aug 2016 31 Jan 2017
# Data gathered for testing period:  01 Feb 2017 28 Feb 2017
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000, 'a', 30, 4.5]
# Data gathered for training period:  01 Sep 2016 28 Feb 2017
# Data gathered for testing period:  01 Mar 2017 31 Mar 2017
# optimisation completed
# Optimal parameters are:  [0.003, 1200000, 'a', 30, 1.0]
# Data gathered for training period:  01 Oct 2016 31 Mar 2017
# Data gathered for testing period:  01 Apr 2017 30 Apr 2017
# optimisation completed
# Optimal parameters are:  [0.0035, 1400000, 'v', 200, 1.0]
# Data gathered for training period:  01 Nov 2016 30 Apr 2017
# Data gathered for testing period:  01 May 2017 31 May 2017
# optimisation completed
# Optimal parameters are:  [0.009, 1500000, 'a', 200, 1.5]
# Data gathered for training period:  01 Dec 2016 31 May 2017
# Data gathered for testing period:  01 Jun 2017 30 Jun 2017
# optimisation completed
# Optimal parameters are:  [0.0045, 1600000, 'a', 200, 4.0]
# Data gathered for training period:  01 Jan 2017 30 Jun 2017
# Data gathered for testing period:  01 Jul 2017 31 Jul 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 1000000, 'v', 20, 5.0]
# Data gathered for training period:  01 Feb 2017 31 Jul 2017
# Data gathered for testing period:  01 Aug 2017 31 Aug 2017
# optimisation completed
# Optimal parameters are:  [0.0065, 1100000, 'v', 9, 5.0]
# Data gathered for training period:  01 Mar 2017 31 Aug 2017
# Data gathered for testing period:  01 Sep 2017 30 Sep 2017
# optimisation completed
# Optimal parameters are:  [0.006, 1500000, 'v', 9, 4.5]
# Data gathered for training period:  01 Apr 2017 30 Sep 2017
# Data gathered for testing period:  01 Oct 2017 31 Oct 2017
# optimisation completed
# Optimal parameters are:  [0.006, 1900000, 'v', 9, 5.0]
# Data gathered for training period:  01 May 2017 31 Oct 2017
# Data gathered for testing period:  01 Nov 2017 30 Nov 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jun 2017 30 Nov 2017
# Data gathered for testing period:  01 Dec 2017 31 Dec 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jul 2017 31 Dec 2017
# Data gathered for testing period:  01 Jan 2018 31 Jan 2018
# optimisation completed
# Optimal parameters are:  [0.007, 1900000, 'v', 100, 5.0]
# Data gathered for training period:  01 Aug 2017 31 Jan 2018
# Data gathered for testing period:  01 Feb 2018 28 Feb 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'a', 200, 5.0]
# Data gathered for training period:  01 Sep 2017 28 Feb 2018
# Data gathered for testing period:  01 Mar 2018 31 Mar 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1600000, 'a', 9, 1.5]
# Data gathered for training period:  01 Oct 2017 31 Mar 2018
# Data gathered for testing period:  01 Apr 2018 30 Apr 2018
# optimisation completed
# Optimal parameters are:  [0.0035, 1400000, 'a', 150, 5.0]
# Data gathered for training period:  01 Nov 2017 30 Apr 2018
# Data gathered for testing period:  01 May 2018 31 May 2018
# optimisation completed
# Optimal parameters are:  [0.005, 1800000, 'v', 20, 4.5]
# Data gathered for training period:  01 Dec 2017 31 May 2018
# Data gathered for testing period:  01 Jun 2018 30 Jun 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 1600000, 'v', 20, 5.0]
# Data gathered for training period:  01 Jan 2018 30 Jun 2018
# Data gathered for testing period:  01 Jul 2018 31 Jul 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 2000000, 'a', 20, 4.0]
# Data gathered for training period:  01 Feb 2018 31 Jul 2018
# Data gathered for testing period:  01 Aug 2018 31 Aug 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 1900000, 'a', 30, 1.0]
# Data gathered for training period:  01 Mar 2018 31 Aug 2018
# Data gathered for testing period:  01 Sep 2018 30 Sep 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'v', 100, 1.5]
# Data gathered for training period:  01 Apr 2018 30 Sep 2018
# Data gathered for testing period:  01 Oct 2018 31 Oct 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'v', 100, 2.0]
# Data gathered for training period:  01 May 2018 31 Oct 2018
# Data gathered for testing period:  01 Nov 2018 30 Nov 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'v', 200, 3.5]
# Data gathered for training period:  01 Jun 2018 30 Nov 2018
# Data gathered for testing period:  01 Dec 2018 31 Dec 2018
# optimisation completed
# Optimal parameters are:  [0.0085, 2000000, 'a', 9, 3.0]
# Data gathered for training period:  01 Jul 2018 31 Dec 2018
# Data gathered for testing period:  01 Jan 2019 31 Jan 2019
# optimisation completed
# Optimal parameters are:  [0.0075, 2000000, 'a', 9, 4.5]
# Data gathered for training period:  01 Aug 2018 31 Jan 2019
# Data gathered for testing period:  01 Feb 2019 28 Feb 2019
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'a', 9, 2.5]
# Data gathered for training period:  01 Sep 2018 28 Feb 2019
# Data gathered for testing period:  01 Mar 2019 31 Mar 2019
# optimisation completed
# Optimal parameters are:  [0.002, 1500000, 'a', 20, 5.0]
# Data gathered for training period:  01 Oct 2018 31 Mar 2019
# Data gathered for testing period:  01 Apr 2019 30 Apr 2019
# optimisation completed
# Optimal parameters are:  [0.003, 1900000, 'a', 9, 4.5]
# Data gathered for training period:  01 Nov 2018 30 Apr 2019
# Data gathered for testing period:  01 May 2019 31 May 2019
# optimisation completed
# Optimal parameters are:  [0.003, 1700000, 'a', 9, 5.0]
# Data gathered for training period:  01 Dec 2018 31 May 2019
# Data gathered for testing period:  01 Jun 2019 30 Jun 2019
# optimisation completed
# Optimal parameters are:  [0.0025, 1700000, 'a', 9, 2.5]
# Data gathered for training period:  01 Jan 2019 30 Jun 2019
# Data gathered for testing period:  01 Jul 2019 31 Jul 2019
# optimisation completed
# Optimal parameters are:  [0.0025, 1800000, 'a', 20, 4.0]
# Data gathered for training period:  01 Feb 2019 31 Jul 2019
# Data gathered for testing period:  01 Aug 2019 31 Aug 2019
# optimisation completed
# Optimal parameters are:  [0.0025, 1700000, 'a', 9, 2.5]
# Data gathered for training period:  01 Mar 2019 31 Aug 2019
# Data gathered for testing period:  01 Sep 2019 30 Sep 2019
# optimisation completed
# Optimal parameters are:  [0.0085, 2000000, 'v', 30, 4.5]
# Data gathered for training period:  01 Apr 2019 30 Sep 2019
# Data gathered for testing period:  01 Oct 2019 31 Oct 2019
# optimisation completed
# Optimal parameters are:  [0.002, 1600000, 'a', 30, 4.0]
# Data gathered for training period:  01 May 2019 31 Oct 2019
# Data gathered for testing period:  01 Nov 2019 30 Nov 2019
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'a', 100, 4.5]
# Data gathered for training period:  01 Jun 2019 30 Nov 2019
# Data gathered for testing period:  01 Dec 2019 31 Dec 2019
# optimisation completed
# Optimal parameters are:  [0.008, 2000000, 'a', 20, 5.0]
# Data gathered for training period:  01 Jul 2019 31 Dec 2019
# Data gathered for testing period:  01 Jan 2020 31 Jan 2020
# optimisation completed
# Optimal parameters are:  [0.004, 1900000, 'v', 30, 4.5]
# Data gathered for training period:  01 Aug 2019 31 Jan 2020
# Data gathered for testing period:  01 Feb 2020 29 Feb 2020
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'a', 9, 4.5]
# Data gathered for training period:  01 Sep 2019 29 Feb 2020
# Data gathered for testing period:  01 Mar 2020 31 Mar 2020
# optimisation completed
# Optimal parameters are:  [0.0045, 2000000, 'a', 100, 1.0]
# Data gathered for training period:  01 Oct 2019 31 Mar 2020
# Data gathered for testing period:  01 Apr 2020 30 Apr 2020
# optimisation completed
# Optimal parameters are:  [0.0075, 1900000, 'a', 9, 4.5]
# Data gathered for training period:  01 Nov 2019 30 Apr 2020
# Data gathered for testing period:  01 May 2020 31 May 2020
# optimisation completed
# Optimal parameters are:  [0.006, 1300000, 'a', 30, 5.0]
# Data gathered for training period:  01 Dec 2019 31 May 2020
# Data gathered for testing period:  01 Jun 2020 30 Jun 2020
# optimisation completed
# Optimal parameters are:  [0.009, 1900000, 'a', 9, 2.0]
# Data gathered for training period:  01 Jan 2020 30 Jun 2020
# Data gathered for testing period:  01 Jul 2020 31 Jul 2020
# optimisation completed
# Optimal parameters are:  [0.0085, 1800000, 'a', 30, 4.0]
# Data gathered for training period:  01 Feb 2020 31 Jul 2020
# Data gathered for testing period:  01 Aug 2020 31 Aug 2020
# optimisation completed
# Optimal parameters are:  [0.002, 2000000, 'v', 50, 5.0]
# Data gathered for training period:  01 Mar 2020 31 Aug 2020
# Data gathered for testing period:  01 Sep 2020 30 Sep 2020
# optimisation completed
# Optimal parameters are:  [0.002, 1500000, 'v', 30, 4.0]
# Data gathered for training period:  01 Apr 2020 30 Sep 2020
# Data gathered for testing period:  01 Oct 2020 31 Oct 2020
# optimisation completed
# Optimal parameters are:  [0.002, 2000000, 'v', 100, 5.0]
# Data gathered for training period:  01 May 2020 31 Oct 2020
# Data gathered for testing period:  01 Nov 2020 30 Nov 2020
# optimisation completed
# Optimal parameters are:  [0.004, 1900000, 'v', 50, 1.0]
# Data gathered for training period:  01 Jun 2020 30 Nov 2020
# Data gathered for testing period:  01 Dec 2020 31 Dec 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 1700000, 'v', 200, 5.0]
# Data gathered for training period:  01 Jul 2020 31 Dec 2020
# Data gathered for testing period:  01 Jan 2021 31 Jan 2021
# optimisation completed
# Optimal parameters are:  [0.0035, 1900000, 'v', 20, 5.0]
# Data gathered for training period:  01 Aug 2020 31 Jan 2021
# Data gathered for testing period:  01 Feb 2021 28 Feb 2021
# optimisation completed
# Optimal parameters are:  [0.0035, 1800000, 'a', 150, 3.0]
# Data gathered for training period:  01 Sep 2020 28 Feb 2021
# Data gathered for testing period:  01 Mar 2021 31 Mar 2021
# optimisation completed
# Optimal parameters are:  [0.0085, 1800000, 'a', 100, 1.5]
# Data gathered for training period:  01 Oct 2020 31 Mar 2021
# Data gathered for testing period:  01 Apr 2021 30 Apr 2021
# optimisation completed
# Optimal parameters are:  [0.0095, 1300000, 'a', 50, 5.0]
# Data gathered for training period:  01 Nov 2020 30 Apr 2021
# Data gathered for testing period:  01 May 2021 31 May 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1100000, 'v', 50, 4.5]
# Data gathered for training period:  01 Dec 2020 31 May 2021
# Data gathered for testing period:  01 Jun 2021 30 Jun 2021
# optimisation completed
# Optimal parameters are:  [0.008, 2000000, 'a', 9, 2.0]
# Data gathered for training period:  01 Jan 2021 30 Jun 2021
# Data gathered for testing period:  01 Jul 2021 31 Jul 2021
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'v', 100, 3.0]
# Data gathered for training period:  01 Feb 2021 31 Jul 2021
# Data gathered for testing period:  01 Aug 2021 31 Aug 2021
# optimisation completed
# Optimal parameters are:  [0.009, 2000000, 'a', 9, 5.0]
# Data gathered for training period:  01 Mar 2021 31 Aug 2021
# Data gathered for testing period:  01 Sep 2021 30 Sep 2021
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'a', 20, 5.0]
# Data gathered for training period:  01 Apr 2021 30 Sep 2021
# Data gathered for testing period:  01 Oct 2021 31 Oct 2021
# optimisation completed
# Optimal parameters are:  [0.008, 800000, 'a', 20, 5.0]
# Data gathered for training period:  01 May 2021 31 Oct 2021
# Data gathered for testing period:  01 Nov 2021 30 Nov 2021
# optimisation completed
# Optimal parameters are:  [0.0075, 1900000, 'v', 20, 5.0]
# Data gathered for training period:  01 Jun 2021 30 Nov 2021
# Data gathered for testing period:  01 Dec 2021 31 Dec 2021
# optimisation completed
# Optimal parameters are:  [0.0045, 1100000, 'v', 30, 5.0]
# Data gathered for training period:  01 Oct 2013 31 Dec 2013
# Data gathered for testing period:  01 Jan 2014 31 Jan 2014
# optimisation completed
# Optimal parameters are:  [0.009, 2000000, 'a', 100, 5.0]
# Data gathered for training period:  01 Nov 2013 31 Jan 2014
# Data gathered for testing period:  01 Feb 2014 28 Feb 2014
# optimisation completed
# Optimal parameters are:  [0.0065, 1600000, 'a', 100, 5.0]
# Data gathered for training period:  01 Dec 2013 28 Feb 2014
# Data gathered for testing period:  01 Mar 2014 31 Mar 2014
# optimisation completed
# Optimal parameters are:  [0.0035, 1000000, 'a', 9, 5.0]
# Data gathered for training period:  01 Jan 2014 31 Mar 2014
# Data gathered for testing period:  01 Apr 2014 30 Apr 2014
# optimisation completed
# Optimal parameters are:  [0.007, 1800000, 'a', 9, 3.0]
# Data gathered for training period:  01 Feb 2014 30 Apr 2014
# Data gathered for testing period:  01 May 2014 31 May 2014
# optimisation completed
# Optimal parameters are:  [0.002, 1400000, 'v', 100, 4.0]
# Data gathered for training period:  01 Mar 2014 31 May 2014
# Data gathered for testing period:  01 Jun 2014 30 Jun 2014
# optimisation completed
# Optimal parameters are:  [0.005, 1900000, 'a', 20, 2.0]
# Data gathered for training period:  01 Apr 2014 30 Jun 2014
# Data gathered for testing period:  01 Jul 2014 31 Jul 2014
# optimisation completed
# Optimal parameters are:  [0.007, 1600000, 'a', 9, 2.5]
# Data gathered for training period:  01 May 2014 31 Jul 2014
# Data gathered for testing period:  01 Aug 2014 31 Aug 2014
# optimisation completed
# Optimal parameters are:  [0.004, 1400000, 'v', 150, 5.0]
# Data gathered for training period:  01 Jun 2014 31 Aug 2014
# Data gathered for testing period:  01 Sep 2014 30 Sep 2014
# optimisation completed
# Optimal parameters are:  [0.002, 1000000, 'v', 20, 5.0]
# Data gathered for training period:  01 Jul 2014 30 Sep 2014
# Data gathered for testing period:  01 Oct 2014 31 Oct 2014
# optimisation completed
# Optimal parameters are:  [0.002, 800000, 'v', 30, 5.0]
# Data gathered for training period:  01 Aug 2014 31 Oct 2014
# Data gathered for testing period:  01 Nov 2014 30 Nov 2014
# optimisation completed
# Optimal parameters are:  [0.005, 1900000, 'v', 150, 4.0]
# Data gathered for training period:  01 Sep 2014 30 Nov 2014
# Data gathered for testing period:  01 Dec 2014 31 Dec 2014
# optimisation completed
# Optimal parameters are:  [0.006, 1700000, 'v', 100, 4.5]
# Data gathered for training period:  01 Oct 2014 31 Dec 2014
# Data gathered for testing period:  01 Jan 2015 31 Jan 2015
# optimisation completed
# Optimal parameters are:  [0.0085, 1400000, 'a', 30, 4.0]
# Data gathered for training period:  01 Nov 2014 31 Jan 2015
# Data gathered for testing period:  01 Feb 2015 28 Feb 2015
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'v', 20, 4.0]
# Data gathered for training period:  01 Dec 2014 28 Feb 2015
# Data gathered for testing period:  01 Mar 2015 31 Mar 2015
# optimisation completed
# Optimal parameters are:  [0.0065, 1700000, 'v', 100, 4.0]
# Data gathered for training period:  01 Jan 2015 31 Mar 2015
# Data gathered for testing period:  01 Apr 2015 30 Apr 2015
# optimisation completed
# Optimal parameters are:  [0.002, 400000, 'v', 20, 5.0]
# Data gathered for training period:  01 Feb 2015 30 Apr 2015
# Data gathered for testing period:  01 May 2015 31 May 2015
# optimisation completed
# Optimal parameters are:  [0.002, 1500000, 'v', 9, 5.0]
# Data gathered for training period:  01 Mar 2015 31 May 2015
# Data gathered for testing period:  01 Jun 2015 30 Jun 2015
# optimisation completed
# Optimal parameters are:  [0.004, 1000000, 'a', 9, 2.0]
# Data gathered for training period:  01 Apr 2015 30 Jun 2015
# Data gathered for testing period:  01 Jul 2015 31 Jul 2015
# optimisation completed
# Optimal parameters are:  [0.0055, 1600000, 'a', 150, 3.0]
# Data gathered for training period:  01 May 2015 31 Jul 2015
# Data gathered for testing period:  01 Aug 2015 31 Aug 2015
# optimisation completed
# Optimal parameters are:  [0.006, 1500000, 'a', 9, 3.0]
# Data gathered for training period:  01 Jun 2015 31 Aug 2015
# Data gathered for testing period:  01 Sep 2015 30 Sep 2015
# optimisation completed
# Optimal parameters are:  [0.006, 1100000, 'a', 20, 4.5]
# Data gathered for training period:  01 Jul 2015 30 Sep 2015
# Data gathered for testing period:  01 Oct 2015 31 Oct 2015
# optimisation completed
# Optimal parameters are:  [0.008, 1500000, 'a', 9, 4.5]
# Data gathered for training period:  01 Aug 2015 31 Oct 2015
# Data gathered for testing period:  01 Nov 2015 30 Nov 2015
# optimisation completed
# Optimal parameters are:  [0.0085, 700000, 'a', 30, 3.0]
# Data gathered for training period:  01 Sep 2015 30 Nov 2015
# Data gathered for testing period:  01 Dec 2015 31 Dec 2015
# optimisation completed
# Optimal parameters are:  [0.0035, 1600000, 'v', 30, 3.0]
# Data gathered for training period:  01 Oct 2015 31 Dec 2015
# Data gathered for testing period:  01 Jan 2016 31 Jan 2016
# optimisation completed
# Optimal parameters are:  [0.004, 1800000, 'v', 9, 5.0]
# Data gathered for training period:  01 Nov 2015 31 Jan 2016
# Data gathered for testing period:  01 Feb 2016 29 Feb 2016
# optimisation completed
# Optimal parameters are:  [0.0015, 1500000, 'a', 150, 1.5]
# Data gathered for training period:  01 Dec 2015 29 Feb 2016
# Data gathered for testing period:  01 Mar 2016 31 Mar 2016
# optimisation completed
# Optimal parameters are:  [0.006, 2000000, 'v', 200, 3.0]
# Data gathered for training period:  01 Jan 2016 31 Mar 2016
# Data gathered for testing period:  01 Apr 2016 30 Apr 2016
# optimisation completed
# Optimal parameters are:  [0.0095, 1900000, 'a', 9, 5.0]
# Data gathered for training period:  01 Feb 2016 30 Apr 2016
# Data gathered for testing period:  01 May 2016 31 May 2016
# optimisation completed
# Optimal parameters are:  [0.004, 2000000, 'v', 150, 5.0]
# Data gathered for training period:  01 Mar 2016 31 May 2016
# Data gathered for testing period:  01 Jun 2016 30 Jun 2016
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Apr 2016 30 Jun 2016
# Data gathered for testing period:  01 Jul 2016 31 Jul 2016
# optimisation completed
# Optimal parameters are:  [0.007, 1800000, 'a', 9, 4.5]
# Data gathered for training period:  01 May 2016 31 Jul 2016
# Data gathered for testing period:  01 Aug 2016 31 Aug 2016
# optimisation completed
# Optimal parameters are:  [0.0015, 800000, 'a', 150, 4.0]
# Data gathered for training period:  01 Jun 2016 31 Aug 2016
# Data gathered for testing period:  01 Sep 2016 30 Sep 2016
# optimisation completed
# Optimal parameters are:  [0.0045, 1800000, 'a', 9, 1.5]
# Data gathered for training period:  01 Jul 2016 30 Sep 2016
# Data gathered for testing period:  01 Oct 2016 31 Oct 2016
# optimisation completed
# Optimal parameters are:  [0.003, 2000000, 'a', 9, 3.0]
# Data gathered for training period:  01 Aug 2016 31 Oct 2016
# Data gathered for testing period:  01 Nov 2016 30 Nov 2016
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000, 'a', 50, 5.0]
# Data gathered for training period:  01 Sep 2016 30 Nov 2016
# Data gathered for testing period:  01 Dec 2016 31 Dec 2016
# optimisation completed
# Optimal parameters are:  [0.003, 1700000, 'v', 20, 4.5]
# Data gathered for training period:  01 Oct 2016 31 Dec 2016
# Data gathered for testing period:  01 Jan 2017 31 Jan 2017
# optimisation completed
# Optimal parameters are:  [0.0065, 1500000, 'v', 150, 5.0]
# Data gathered for training period:  01 Nov 2016 31 Jan 2017
# Data gathered for testing period:  01 Feb 2017 28 Feb 2017
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000, 'a', 9, 2.5]
# Data gathered for training period:  01 Dec 2016 28 Feb 2017
# Data gathered for testing period:  01 Mar 2017 31 Mar 2017
# optimisation completed
# Optimal parameters are:  [0.0045, 1600000, 'a', 150, 3.0]
# Data gathered for training period:  01 Jan 2017 31 Mar 2017
# Data gathered for testing period:  01 Apr 2017 30 Apr 2017
# optimisation completed
# Optimal parameters are:  [0.0035, 2000000, 'a', 30, 2.0]
# Data gathered for training period:  01 Feb 2017 30 Apr 2017
# Data gathered for testing period:  01 May 2017 31 May 2017
# optimisation completed
# Optimal parameters are:  [0.009, 1600000, 'a', 50, 5.0]
# Data gathered for training period:  01 Mar 2017 31 May 2017
# Data gathered for testing period:  01 Jun 2017 30 Jun 2017
# optimisation completed
# Optimal parameters are:  [0.0085, 1800000, 'v', 9, 5.0]
# Data gathered for training period:  01 Apr 2017 30 Jun 2017
# Data gathered for testing period:  01 Jul 2017 31 Jul 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 100, 5.0]
# Data gathered for training period:  01 May 2017 31 Jul 2017
# Data gathered for testing period:  01 Aug 2017 31 Aug 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 1600000, 'v', 30, 5.0]
# Data gathered for training period:  01 Jun 2017 31 Aug 2017
# Data gathered for testing period:  01 Sep 2017 30 Sep 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Jul 2017 30 Sep 2017
# Data gathered for testing period:  01 Oct 2017 31 Oct 2017
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'v', 100, 5.0]
# Data gathered for training period:  01 Aug 2017 31 Oct 2017
# Data gathered for testing period:  01 Nov 2017 30 Nov 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'a', 30, 4.0]
# Data gathered for training period:  01 Sep 2017 30 Nov 2017
# Data gathered for testing period:  01 Dec 2017 31 Dec 2017
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'a', 50, 2.5]
# Data gathered for training period:  01 Oct 2017 31 Dec 2017
# Data gathered for testing period:  01 Jan 2018 31 Jan 2018
# optimisation completed
# Optimal parameters are:  [0.006, 2000000, 'a', 9, 4.5]
# Data gathered for training period:  01 Nov 2017 31 Jan 2018
# Data gathered for testing period:  01 Feb 2018 28 Feb 2018
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'v', 9, 4.5]
# Data gathered for training period:  01 Dec 2017 28 Feb 2018
# Data gathered for testing period:  01 Mar 2018 31 Mar 2018
# optimisation completed
# Optimal parameters are:  [0.0035, 1300000, 'a', 150, 5.0]
# Data gathered for training period:  01 Jan 2018 31 Mar 2018
# Data gathered for testing period:  01 Apr 2018 30 Apr 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1800000, 'a', 200, 5.0]
# Data gathered for training period:  01 Feb 2018 30 Apr 2018
# Data gathered for testing period:  01 May 2018 31 May 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 1900000, 'a', 9, 2.0]
# Data gathered for training period:  01 Mar 2018 31 May 2018
# Data gathered for testing period:  01 Jun 2018 30 Jun 2018
# optimisation completed
# Optimal parameters are:  [0.0035, 1500000, 'v', 20, 4.5]
# Data gathered for training period:  01 Apr 2018 30 Jun 2018
# Data gathered for testing period:  01 Jul 2018 31 Jul 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 2000000, 'v', 50, 5.0]
# Data gathered for training period:  01 May 2018 31 Jul 2018
# Data gathered for testing period:  01 Aug 2018 31 Aug 2018
# optimisation completed
# Optimal parameters are:  [0.0025, 1200000, 'v', 200, 5.0]
# Data gathered for training period:  01 Jun 2018 31 Aug 2018
# Data gathered for testing period:  01 Sep 2018 30 Sep 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1500000, 'a', 9, 4.5]
# Data gathered for training period:  01 Jul 2018 30 Sep 2018
# Data gathered for testing period:  01 Oct 2018 31 Oct 2018
# optimisation completed
# Optimal parameters are:  [0.0075, 2000000, 'a', 9, 5.0]
# Data gathered for training period:  01 Aug 2018 31 Oct 2018
# Data gathered for testing period:  01 Nov 2018 30 Nov 2018
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'v', 200, 3.0]
# Data gathered for training period:  01 Sep 2018 30 Nov 2018
# Data gathered for testing period:  01 Dec 2018 31 Dec 2018
# optimisation completed
# Optimal parameters are:  [0.0015, 1400000, 'a', 50, 4.5]
# Data gathered for training period:  01 Oct 2018 31 Dec 2018
# Data gathered for testing period:  01 Jan 2019 31 Jan 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1400000, 'a', 100, 1.5]
# Data gathered for training period:  01 Nov 2018 31 Jan 2019
# Data gathered for testing period:  01 Feb 2019 28 Feb 2019
# optimisation completed
# Optimal parameters are:  [0.0035, 2000000, 'a', 9, 4.5]
# Data gathered for training period:  01 Dec 2018 28 Feb 2019
# Data gathered for testing period:  01 Mar 2019 31 Mar 2019
# optimisation completed
# Optimal parameters are:  [0.0025, 1600000, 'a', 9, 4.5]
# Data gathered for training period:  01 Jan 2019 31 Mar 2019
# Data gathered for testing period:  01 Apr 2019 30 Apr 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1900000, 'v', 9, 4.5]
# Data gathered for training period:  01 Feb 2019 30 Apr 2019
# Data gathered for testing period:  01 May 2019 31 May 2019
# optimisation completed
# Optimal parameters are:  [0.001, 2000000, 'v', 9, 4.0]
# Data gathered for training period:  01 Mar 2019 31 May 2019
# Data gathered for testing period:  01 Jun 2019 30 Jun 2019
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Apr 2019 30 Jun 2019
# Data gathered for testing period:  01 Jul 2019 31 Jul 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1800000, 'a', 200, 4.5]
# Data gathered for training period:  01 May 2019 31 Jul 2019
# Data gathered for testing period:  01 Aug 2019 31 Aug 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1500000, 'a', 30, 5.0]
# Data gathered for training period:  01 Jun 2019 31 Aug 2019
# Data gathered for testing period:  01 Sep 2019 30 Sep 2019
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'a', 150, 5.0]
# Data gathered for training period:  01 Jul 2019 30 Sep 2019
# Data gathered for testing period:  01 Oct 2019 31 Oct 2019
# optimisation completed
# Optimal parameters are:  [0.004, 2000000, 'v', 200, 5.0]
# Data gathered for training period:  01 Aug 2019 31 Oct 2019
# Data gathered for testing period:  01 Nov 2019 30 Nov 2019
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'a', 9, 5.0]
# Data gathered for training period:  01 Sep 2019 30 Nov 2019
# Data gathered for testing period:  01 Dec 2019 31 Dec 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1200000, 'a', 200, 4.5]
# Data gathered for training period:  01 Oct 2019 31 Dec 2019
# Data gathered for testing period:  01 Jan 2020 31 Jan 2020
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'v', 50, 4.5]
# Data gathered for training period:  01 Nov 2019 31 Jan 2020
# Data gathered for testing period:  01 Feb 2020 29 Feb 2020
# optimisation completed
# Optimal parameters are:  [0.0035, 2000000, 'a', 150, 5.0]
# Data gathered for training period:  01 Dec 2019 29 Feb 2020
# Data gathered for testing period:  01 Mar 2020 31 Mar 2020
# optimisation completed
# Optimal parameters are:  [0.005, 1800000, 'a', 100, 5.0]
# Data gathered for training period:  01 Jan 2020 31 Mar 2020
# Data gathered for testing period:  01 Apr 2020 30 Apr 2020
# optimisation completed
# Optimal parameters are:  [0.002, 1500000, 'v', 50, 5.0]
# Data gathered for training period:  01 Feb 2020 30 Apr 2020
# Data gathered for testing period:  01 May 2020 31 May 2020
# optimisation completed
# Optimal parameters are:  [0.002, 2000000, 'v', 30, 4.5]
# Data gathered for training period:  01 Mar 2020 31 May 2020
# Data gathered for testing period:  01 Jun 2020 30 Jun 2020
# optimisation completed
# Optimal parameters are:  [0.01, 2000000, 'a', 9, 4.5]
# Data gathered for training period:  01 Apr 2020 30 Jun 2020
# Data gathered for testing period:  01 Jul 2020 31 Jul 2020
# optimisation completed
# Optimal parameters are:  [0.01, 2000000, 'a', 50, 5.0]
# Data gathered for training period:  01 May 2020 31 Jul 2020
# Data gathered for testing period:  01 Aug 2020 31 Aug 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 1400000, 'v', 50, 3.5]
# Data gathered for training period:  01 Jun 2020 31 Aug 2020
# Data gathered for testing period:  01 Sep 2020 30 Sep 2020
# optimisation completed
# Optimal parameters are:  [0.002, 700000, 'v', 20, 4.0]
# Data gathered for training period:  01 Jul 2020 30 Sep 2020
# Data gathered for testing period:  01 Oct 2020 31 Oct 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 1300000, 'v', 200, 5.0]
# Data gathered for training period:  01 Aug 2020 31 Oct 2020
# Data gathered for testing period:  01 Nov 2020 30 Nov 2020
# optimisation completed
# Optimal parameters are:  [0.0035, 1800000, 'a', 9, 5.0]
# Data gathered for training period:  01 Sep 2020 30 Nov 2020
# Data gathered for testing period:  01 Dec 2020 31 Dec 2020
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000, 'a', 150, 1.5]
# Data gathered for training period:  01 Oct 2020 31 Dec 2020
# Data gathered for testing period:  01 Jan 2021 31 Jan 2021
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Nov 2020 31 Jan 2021
# Data gathered for testing period:  01 Feb 2021 28 Feb 2021
# optimisation completed
# Optimal parameters are:  [0.006, 2000000, 'v', 9, 4.5]
# Data gathered for training period:  01 Dec 2020 28 Feb 2021
# Data gathered for testing period:  01 Mar 2021 31 Mar 2021
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'a', 9, 5.0]
# Data gathered for training period:  01 Jan 2021 31 Mar 2021
# Data gathered for testing period:  01 Apr 2021 30 Apr 2021
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Feb 2021 30 Apr 2021
# Data gathered for testing period:  01 May 2021 31 May 2021
# optimisation completed
# Optimal parameters are:  [0.0075, 1900000, 'a', 20, 5.0]
# Data gathered for training period:  01 Mar 2021 31 May 2021
# Data gathered for testing period:  01 Jun 2021 30 Jun 2021
# optimisation completed
# Optimal parameters are:  [0.008, 1300000, 'a', 30, 5.0]
# Data gathered for training period:  01 Apr 2021 30 Jun 2021
# Data gathered for testing period:  01 Jul 2021 31 Jul 2021
# optimisation completed
# Optimal parameters are:  [0.009, 1200000, 'a', 20, 5.0]
# Data gathered for training period:  01 May 2021 31 Jul 2021
# Data gathered for testing period:  01 Aug 2021 31 Aug 2021
# optimisation completed
# Optimal parameters are:  [0.009, 1900000, 'a', 20, 4.0]
# Data gathered for training period:  01 Jun 2021 31 Aug 2021
# Data gathered for testing period:  01 Sep 2021 30 Sep 2021
# optimisation completed
# Optimal parameters are:  [0.0035, 2000000, 'v', 50, 5.0]
# Data gathered for training period:  01 Jul 2021 30 Sep 2021
# Data gathered for testing period:  01 Oct 2021 31 Oct 2021
# optimisation completed
# Optimal parameters are:  [0.001, 2000000, 'a', 150, 5.0]
# Data gathered for training period:  01 Aug 2021 31 Oct 2021
# Data gathered for testing period:  01 Nov 2021 30 Nov 2021
# optimisation completed
# Optimal parameters are:  [0.0095, 2000000, 'v', 9, 5.0]
# Data gathered for training period:  01 Sep 2021 30 Nov 2021
# Data gathered for testing period:  01 Dec 2021 31 Dec 2021
# optimisation completed
# Optimal parameters are:  [0.001, 400000, 'v', 50, 5.0]

# %%
Profit_Analysis('EURGBP','profit','3-1')

# %%
Profit_Analysis('EURGBP','profit','6-1')

# %%
Profit_Analysis('EURGBP','profit','12-1')
