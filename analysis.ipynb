# %% [markdown]
# # Analyze drawdowns

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
import pandas as pd
from bp import data_gather_from_files,run_strategy_optimised,run_strategy_eval
import time
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ## Group 1

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Run for loss month

# %%
Test_data = data_gather_from_files('1 mar 2021','31 mar 2021')['EURUSD.mid']
# fix grid size
G = 0.006
for n in range(100_000,2_100_000,100_000):
    maxloss,_,profit = run_strategy_optimised(Test_data,G,n)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.006 , n= 100000 is : -5450.0
# profit for G = 0.006 , n= 200000 is : -10900.0
# profit for G = 0.006 , n= 300000 is : -16350.0
# profit for G = 0.006 , n= 400000 is : -21800.0
# profit for G = 0.006 , n= 500000 is : -27250.0
# profit for G = 0.006 , n= 600000 is : -32700.0
# profit for G = 0.006 , n= 700000 is : -38150.0
# profit for G = 0.006 , n= 800000 is : -43600.0
# profit for G = 0.006 , n= 900000 is : -49050.0
# profit for G = 0.006 , n= 1000000 is : -54500.0
# profit for G = 0.006 , n= 1100000 is : -59950.0
# profit for G = 0.006 , n= 1200000 is : -65400.0
# profit for G = 0.006 , n= 1300000 is : -70850.0
# profit for G = 0.006 , n= 1400000 is : -76300.0
# profit for G = 0.006 , n= 1500000 is : -81750.0
# profit for G = 0.006 , n= 1600000 is : -87200.0
# profit for G = 0.006 , n= 1700000 is : -86360.0
# profit for G = 0.006 , n= 1800000 is : -91440.0
# profit for G = 0.006 , n= 1900000 is : -96520.0
# profit for G = 0.006 , n= 2000000 is : -101600.0

# %%
Test_data = data_gather_from_files('1 mar 2021','31 mar 2021')['EURUSD.mid']
# fix lot size
n= 1_300_000
for G in np.arange(0.001,0.0101,0.0005):
    G=np.round(G,4)
    maxloss,_,profit = run_strategy_optimised(Test_data,G,n)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.001 , n= 1300000 is : -79560.0
# profit for G = 0.0015 , n= 1300000 is : -101010.0
# profit for G = 0.002 , n= 1300000 is : -117260.0
# profit for G = 0.0025 , n= 1300000 is : -128310.0
# profit for G = 0.003 , n= 1300000 is : -161460.0
# profit for G = 0.0035 , n= 1300000 is : -155050.5001
# profit for G = 0.004 , n= 1300000 is : -158860.0
# profit for G = 0.0045 , n= 1300000 is : -99060.0
# profit for G = 0.005 , n= 1300000 is : -79560.0
# profit for G = 0.0055 , n= 1300000 is : -65260.0
# profit for G = 0.006 , n= 1300000 is : -70850.0
# profit for G = 0.0065 , n= 1300000 is : -134160.0
# profit for G = 0.007 , n= 1300000 is : -37440.0
# profit for G = 0.0075 , n= 1300000 is : -111800.0
# profit for G = 0.008 , n= 1300000 is : -107250.0
# profit for G = 0.0085 , n= 1300000 is : -92950.0
# profit for G = 0.009 , n= 1300000 is : -93340.0
# profit for G = 0.0095 , n= 1300000 is : -91390.0
# profit for G = 0.01 , n= 1300000 is : -7020.0

# %%
Test_data = data_gather_from_files('1 mar 2021','31 mar 2021')['EURUSD.mid']
# fix lot size
for G in np.arange(0.001,0.0101,0.0005):
    G=np.round(G,4)
    for n in range(100_000,2_100_000,100_000):
        maxloss,_,profit = run_strategy_optimised(Test_data,G,n)
        print(f'profit for G = {G} , n= {n} is : {profit}')
        #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.001 , n= 100000 is : -50860.0
# profit for G = 0.001 , n= 200000 is : -101720.0
# profit for G = 0.001 , n= 300000 is : -139980.0
# profit for G = 0.001 , n= 400000 is : -146680.0
# profit for G = 0.001 , n= 500000 is : -142100.0
# profit for G = 0.001 , n= 600000 is : -136080.0
# profit for G = 0.001 , n= 700000 is : -123480.0
# profit for G = 0.001 , n= 800000 is : -111200.0
# profit for G = 0.001 , n= 900000 is : -100170.0
# profit for G = 0.001 , n= 1000000 is : -82600.0
# profit for G = 0.001 , n= 1100000 is : -74690.0
# profit for G = 0.001 , n= 1200000 is : -75480.0
# profit for G = 0.001 , n= 1300000 is : -79560.0
# profit for G = 0.001 , n= 1400000 is : -89880.0
# profit for G = 0.001 , n= 1500000 is : -84750.0
# profit for G = 0.001 , n= 1600000 is : -90400.0
# profit for G = 0.001 , n= 1700000 is : -96560.0
# profit for G = 0.001 , n= 1800000 is : -102240.0
# profit for G = 0.001 , n= 1900000 is : -107920.0
# ...

# %% [markdown]
# # run for profit month

# %%
Test_data2 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid']
# fix grid size
G = 0.0045
for n in range(100_000,2_100_000,100_000):
    maxloss,_,profit = run_strategy_optimised(Test_data2,G,n)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0045 , n= 100000 is : 2430.0
# profit for G = 0.0045 , n= 200000 is : 4860.0
# profit for G = 0.0045 , n= 300000 is : 7290.0
# profit for G = 0.0045 , n= 400000 is : 9720.0
# profit for G = 0.0045 , n= 500000 is : 12150.0
# profit for G = 0.0045 , n= 600000 is : 14580.0
# profit for G = 0.0045 , n= 700000 is : 17010.0
# profit for G = 0.0045 , n= 800000 is : 19440.0
# profit for G = 0.0045 , n= 900000 is : 21870.0
# profit for G = 0.0045 , n= 1000000 is : 24300.0
# profit for G = 0.0045 , n= 1100000 is : 26730.0
# profit for G = 0.0045 , n= 1200000 is : 29160.0
# profit for G = 0.0045 , n= 1300000 is : 31590.0
# profit for G = 0.0045 , n= 1400000 is : 34020.0
# profit for G = 0.0045 , n= 1500000 is : 36450.0
# profit for G = 0.0045 , n= 1600000 is : 38880.0
# profit for G = 0.0045 , n= 1700000 is : 41310.0
# profit for G = 0.0045 , n= 1800000 is : 43740.0
# profit for G = 0.0045 , n= 1900000 is : 46170.0
# profit for G = 0.0045 , n= 2000000 is : 48600.0

# %%
Test_data2 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid']
# fix lot size
n= 2_000_000
for G in np.arange(0.001,0.0101,0.0005):
    G=np.round(G,4)
    maxloss,_,profit = run_strategy_optimised(Test_data2,G,n)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.001 , n= 2000000 is : 60200.0
# profit for G = 0.0015 , n= 2000000 is : 108000.0
# profit for G = 0.002 , n= 2000000 is : 42200.0
# profit for G = 0.0025 , n= 2000000 is : 64400.0
# profit for G = 0.003 , n= 2000000 is : 62400.0
# profit for G = 0.0035 , n= 2000000 is : 3400.0
# profit for G = 0.004 , n= 2000000 is : -17400.0
# profit for G = 0.0045 , n= 2000000 is : 48600.0
# profit for G = 0.005 , n= 2000000 is : -13400.0
# profit for G = 0.0055 , n= 2000000 is : -24600.0
# profit for G = 0.006 , n= 2000000 is : 18600.0
# profit for G = 0.0065 , n= 2000000 is : 32200.0
# profit for G = 0.007 , n= 2000000 is : -19400.0
# profit for G = 0.0075 , n= 2000000 is : 67200.0
# profit for G = 0.008 , n= 2000000 is : 58200.0
# profit for G = 0.0085 , n= 2000000 is : 3400.0
# profit for G = 0.009 , n= 2000000 is : 2400.0
# profit for G = 0.0095 , n= 2000000 is : 7400.0
# profit for G = 0.01 , n= 2000000 is : 22200.0

# %%
Test_data2 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid']
for G in np.arange(0.001,0.0101,0.0005):
    G=np.round(G,4)
    for n in range(100_000,2_100_000,100_000):
        maxloss,_,profit = run_strategy_optimised(Test_data2,G,n)
        print(f'profit for G = {G} , n= {n} is : {profit}')
        #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.001 , n= 100000 is : 6350.0
# profit for G = 0.001 , n= 200000 is : 12700.0
# profit for G = 0.001 , n= 300000 is : 19050.0
# profit for G = 0.001 , n= 400000 is : 20120.0
# profit for G = 0.001 , n= 500000 is : 17950.0
# profit for G = 0.001 , n= 600000 is : 21360.0
# profit for G = 0.001 , n= 700000 is : 28280.0
# profit for G = 0.001 , n= 800000 is : 35440.0
# profit for G = 0.001 , n= 900000 is : 44280.0
# profit for G = 0.001 , n= 1000000 is : 55100.0
# profit for G = 0.001 , n= 1100000 is : 68200.0
# profit for G = 0.001 , n= 1200000 is : 83880.0
# profit for G = 0.001 , n= 1300000 is : 90870.0
# profit for G = 0.001 , n= 1400000 is : 67200.0
# profit for G = 0.001 , n= 1500000 is : 72000.0
# profit for G = 0.001 , n= 1600000 is : 76800.0
# profit for G = 0.001 , n= 1700000 is : 51170.0
# profit for G = 0.001 , n= 1800000 is : 54180.0
# profit for G = 0.001 , n= 1900000 is : 57190.0
# profit for G = 0.001 , n= 2000000 is : 60200.0
# ...

# %% [markdown]
# ## Summary for Group 1
# * for group 1 strategy, Profit/Loss will multiplied according to lot size
# * Grid size is the most important parameter to determine it will get profit/loss. Lot size is like multiplier.

# %% [markdown]
# # Group 2 (drop)

# %% [markdown]
# # Group 3

# %% [markdown]
# ### Loss month

# %%
Test_data4 = data_gather_from_files('1 june 2021','30 june 2021')['EURUSD.mid']
# fix grid size, indicator scale and lookback
lb = 200
G = 0.0075
ind_scale = 2
type = 'v'
for n in range(100_000,2_100_000,100_000):
    maxloss,_,profit = run_strategy_optimised(Test_data4, G, n, indicator_type = type, lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 100000 is : -7800.0
# profit for G = 0.0075 , n= 200000 is : -15600.0
# profit for G = 0.0075 , n= 300000 is : -23400.0
# profit for G = 0.0075 , n= 400000 is : -31200.0
# profit for G = 0.0075 , n= 500000 is : -39000.0
# profit for G = 0.0075 , n= 600000 is : -46800.0
# profit for G = 0.0075 , n= 700000 is : -54600.0
# profit for G = 0.0075 , n= 800000 is : -62400.0
# profit for G = 0.0075 , n= 900000 is : -70200.0
# profit for G = 0.0075 , n= 1000000 is : -78000.0
# profit for G = 0.0075 , n= 1100000 is : -85800.0
# profit for G = 0.0075 , n= 1200000 is : -93600.0
# profit for G = 0.0075 , n= 1300000 is : -101400.0
# profit for G = 0.0075 , n= 1400000 is : -143700.0
# profit for G = 0.0075 , n= 1500000 is : -143250.0
# profit for G = 0.0075 , n= 1600000 is : -142800.0
# profit for G = 0.0075 , n= 1700000 is : -142350.0
# profit for G = 0.0075 , n= 1800000 is : -141900.0
# profit for G = 0.0075 , n= 1900000 is : -141450.0
# ...

# %%
# change indicator type
Test_data4 = data_gather_from_files('1 june 2021','30 june 2021')['EURUSD.mid']
# fix grid size, indicator scale and lookback
lb = 200
G = 0.0075
ind_scale = 2
type = 'a'
for n in range(100_000,2_100_000,100_000):
    maxloss,_,profit = run_strategy_optimised(Test_data4, G, n, indicator_type = type, lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 100000 is : -8000.0
# profit for G = 0.0075 , n= 200000 is : -16000.0
# profit for G = 0.0075 , n= 300000 is : -24000.0
# profit for G = 0.0075 , n= 400000 is : -32000.0
# profit for G = 0.0075 , n= 500000 is : -40000.0
# profit for G = 0.0075 , n= 600000 is : -48000.0
# profit for G = 0.0075 , n= 700000 is : -56000.0
# profit for G = 0.0075 , n= 800000 is : -64000.0
# profit for G = 0.0075 , n= 900000 is : -72000.0
# profit for G = 0.0075 , n= 1000000 is : -80000.0
# profit for G = 0.0075 , n= 1100000 is : -88000.0
# profit for G = 0.0075 , n= 1200000 is : -96000.0
# profit for G = 0.0075 , n= 1300000 is : -104000.0
# profit for G = 0.0075 , n= 1400000 is : -146500.0
# profit for G = 0.0075 , n= 1500000 is : -146250.0
# profit for G = 0.0075 , n= 1600000 is : -146000.0
# profit for G = 0.0075 , n= 1700000 is : -145750.0
# profit for G = 0.0075 , n= 1800000 is : -145500.0
# profit for G = 0.0075 , n= 1900000 is : -145250.0
# ...

# %% [markdown]
# ### Profit month

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid']
# fix grid size, indicator scale and lookback
lb = 200
G = 0.0075
ind_scale = 2
type = 'v'
for n in range(100_000,2_100_000,100_000):
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = type, lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 100000 is : 4347.0
# profit for G = 0.0075 , n= 200000 is : 8694.0
# profit for G = 0.0075 , n= 300000 is : 13041.0
# profit for G = 0.0075 , n= 400000 is : 17388.0
# profit for G = 0.0075 , n= 500000 is : 21735.0
# profit for G = 0.0075 , n= 600000 is : 26082.0
# profit for G = 0.0075 , n= 700000 is : 30429.0
# profit for G = 0.0075 , n= 800000 is : 34776.0
# profit for G = 0.0075 , n= 900000 is : 39123.0
# profit for G = 0.0075 , n= 1000000 is : 43470.0
# profit for G = 0.0075 , n= 1100000 is : 47817.0
# profit for G = 0.0075 , n= 1200000 is : 52164.0
# profit for G = 0.0075 , n= 1300000 is : 56511.0
# profit for G = 0.0075 , n= 1400000 is : 60858.0
# profit for G = 0.0075 , n= 1500000 is : 65205.0
# profit for G = 0.0075 , n= 1600000 is : 69552.0
# profit for G = 0.0075 , n= 1700000 is : 73899.0
# profit for G = 0.0075 , n= 1800000 is : 78246.0
# profit for G = 0.0075 , n= 1900000 is : 82593.0
# profit for G = 0.0075 , n= 2000000 is : 86940.0

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid']
# fix grid size, indicator scale and lookback
lb = 200
G = 0.0075
ind_scale = 2
type = 'a'
for n in range(100_000,2_100_000,100_000):
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = type, lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 100000 is : 4449.0
# profit for G = 0.0075 , n= 200000 is : 8898.0
# profit for G = 0.0075 , n= 300000 is : 13347.0
# profit for G = 0.0075 , n= 400000 is : 17796.0
# profit for G = 0.0075 , n= 500000 is : 22245.0
# profit for G = 0.0075 , n= 600000 is : 26694.0
# profit for G = 0.0075 , n= 700000 is : 31143.0
# profit for G = 0.0075 , n= 800000 is : 35592.0
# profit for G = 0.0075 , n= 900000 is : 40041.0
# profit for G = 0.0075 , n= 1000000 is : 44490.0
# profit for G = 0.0075 , n= 1100000 is : 48939.0
# profit for G = 0.0075 , n= 1200000 is : 53388.0
# profit for G = 0.0075 , n= 1300000 is : 57837.0
# profit for G = 0.0075 , n= 1400000 is : 62286.0
# profit for G = 0.0075 , n= 1500000 is : 66735.0
# profit for G = 0.0075 , n= 1600000 is : 71184.0
# profit for G = 0.0075 , n= 1700000 is : 75633.0
# profit for G = 0.0075 , n= 1800000 is : 80082.0
# profit for G = 0.0075 , n= 1900000 is : 84531.0
# profit for G = 0.0075 , n= 2000000 is : 88980.0

# %% [markdown]
# lot size is multiplier of profit/loss

# %% [markdown]
# ?? Type a give more abs number = more profit and more loss?? >> not true

# %% [markdown]
# # Lets fix to type 'v' then we will compare to type 'a' later & let's fix lot size

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid'] # profit month
# fix lot size, indicator scale and lookback
lb = 200
n=200_000
ind_scale = 2
for G in np.arange(0.001,0.0101,0.0005):
    G=np.round(G,4)
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.001 , n= 200000 is : 10636.0
# profit for G = 0.0015 , n= 200000 is : 11118.0
# profit for G = 0.002 , n= 200000 is : 5644.0
# profit for G = 0.0025 , n= 200000 is : 8788.0
# profit for G = 0.003 , n= 200000 is : 9384.0
# profit for G = 0.0035 , n= 200000 is : 4310.0
# profit for G = 0.004 , n= 200000 is : 580.0
# profit for G = 0.0045 , n= 200000 is : 6636.0
# profit for G = 0.005 , n= 200000 is : 1294.0
# profit for G = 0.0055 , n= 200000 is : -522.0
# profit for G = 0.006 , n= 200000 is : 3672.0
# profit for G = 0.0065 , n= 200000 is : 4748.0
# profit for G = 0.007 , n= 200000 is : -744.0
# profit for G = 0.0075 , n= 200000 is : 8694.0
# profit for G = 0.008 , n= 200000 is : 6938.0
# profit for G = 0.0085 , n= 200000 is : 2278.0
# profit for G = 0.009 , n= 200000 is : 2100.0
# profit for G = 0.0095 , n= 200000 is : 2708.0
# profit for G = 0.01 , n= 200000 is : 1686.0

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid'] # profit month
# fix lot size, indicator scale and lookback
lb = 200
n=2_000_000
ind_scale = 2
for G in np.arange(0.001,0.0101,0.0005):
    G=np.round(G,4)
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.001 , n= 2000000 is : 14620.0
# profit for G = 0.0015 , n= 2000000 is : 53580.0
# profit for G = 0.002 , n= 2000000 is : 81440.0
# profit for G = 0.0025 , n= 2000000 is : 98480.0
# profit for G = 0.003 , n= 2000000 is : 83640.0
# profit for G = 0.0035 , n= 2000000 is : 32700.0
# profit for G = 0.004 , n= 2000000 is : 1400.0
# profit for G = 0.0045 , n= 2000000 is : 66360.0
# profit for G = 0.005 , n= 2000000 is : 740.0
# profit for G = 0.0055 , n= 2000000 is : -20420.0
# profit for G = 0.006 , n= 2000000 is : 36720.0
# profit for G = 0.0065 , n= 2000000 is : 47480.0
# profit for G = 0.007 , n= 2000000 is : -7440.0
# profit for G = 0.0075 , n= 2000000 is : 86940.0
# profit for G = 0.008 , n= 2000000 is : 69380.0
# profit for G = 0.0085 , n= 2000000 is : 22780.0
# profit for G = 0.009 , n= 2000000 is : 21000.0
# profit for G = 0.0095 , n= 2000000 is : 27080.0
# profit for G = 0.01 , n= 2000000 is : 16860.0

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid'] # profit month
# fix grid size, lot size and lookback
G=0.0075
lb = 200
n=200_000
for ind_scale in np.arange(1,3.01,0.1):
    ind_scale=np.round(ind_scale,1)
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 1.0 is : 7632.0
# profit for G = 0.0075 , n= 200000 , scale = 1.1 is : 7632.0
# profit for G = 0.0075 , n= 200000 , scale = 1.2 is : 8466.0
# profit for G = 0.0075 , n= 200000 , scale = 1.3 is : 8466.0
# profit for G = 0.0075 , n= 200000 , scale = 1.4 is : 8238.0
# profit for G = 0.0075 , n= 200000 , scale = 1.5 is : 8010.0
# profit for G = 0.0075 , n= 200000 , scale = 1.6 is : 8010.0
# profit for G = 0.0075 , n= 200000 , scale = 1.7 is : 8694.0
# profit for G = 0.0075 , n= 200000 , scale = 1.8 is : 8694.0
# profit for G = 0.0075 , n= 200000 , scale = 1.9 is : 8694.0
# profit for G = 0.0075 , n= 200000 , scale = 2.0 is : 8694.0
# profit for G = 0.0075 , n= 200000 , scale = 2.1 is : 9072.0
# profit for G = 0.0075 , n= 200000 , scale = 2.2 is : 9300.0
# profit for G = 0.0075 , n= 200000 , scale = 2.3 is : 9378.0
# profit for G = 0.0075 , n= 200000 , scale = 2.4 is : 9378.0
# profit for G = 0.0075 , n= 200000 , scale = 2.5 is : 8922.0
# ...

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid'] # profit month
# fix grid size, lot size and lookback
G=0.0075
lb = 200
n=200_000
for ind_scale in np.arange(10,50,1):
    ind_scale=np.round(ind_scale,1)
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 10 is : 17574.0
# profit for G = 0.0075 , n= 200000 , scale = 11 is : 18714.0
# profit for G = 0.0075 , n= 200000 , scale = 12 is : 19776.0
# profit for G = 0.0075 , n= 200000 , scale = 13 is : 20688.0
# profit for G = 0.0075 , n= 200000 , scale = 14 is : 21900.0
# profit for G = 0.0075 , n= 200000 , scale = 15 is : 23040.0
# profit for G = 0.0075 , n= 200000 , scale = 16 is : 24180.0
# profit for G = 0.0075 , n= 200000 , scale = 17 is : 25014.0
# profit for G = 0.0075 , n= 200000 , scale = 18 is : 26154.0
# profit for G = 0.0075 , n= 200000 , scale = 19 is : 27594.0
# profit for G = 0.0075 , n= 200000 , scale = 20 is : 28506.0
# profit for G = 0.0075 , n= 200000 , scale = 21 is : 29340.0
# profit for G = 0.0075 , n= 200000 , scale = 22 is : 30708.0
# profit for G = 0.0075 , n= 200000 , scale = 23 is : 31542.0
# profit for G = 0.0075 , n= 200000 , scale = 24 is : 32454.0
# profit for G = 0.0075 , n= 200000 , scale = 25 is : 33894.0
# ...

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid'] # profit month
# fix grid size, lot size and lookback
G=0.0075
lb = 200
n=200_000
for ind_scale in np.arange(10,50,1):
    ind_scale=np.round(ind_scale,1)
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = 'a', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 10 is : 17460.0
# profit for G = 0.0075 , n= 200000 , scale = 11 is : 18510.0
# profit for G = 0.0075 , n= 200000 , scale = 12 is : 19560.0
# profit for G = 0.0075 , n= 200000 , scale = 13 is : 20460.0
# profit for G = 0.0075 , n= 200000 , scale = 14 is : 21588.0
# profit for G = 0.0075 , n= 200000 , scale = 15 is : 22638.0
# profit for G = 0.0075 , n= 200000 , scale = 16 is : 23766.0
# profit for G = 0.0075 , n= 200000 , scale = 17 is : 24894.0
# profit for G = 0.0075 , n= 200000 , scale = 18 is : 25716.0
# profit for G = 0.0075 , n= 200000 , scale = 19 is : 26766.0
# profit for G = 0.0075 , n= 200000 , scale = 20 is : 27816.0
# profit for G = 0.0075 , n= 200000 , scale = 21 is : 29022.0
# profit for G = 0.0075 , n= 200000 , scale = 22 is : 30150.0
# profit for G = 0.0075 , n= 200000 , scale = 23 is : 31272.0
# profit for G = 0.0075 , n= 200000 , scale = 24 is : 32400.0
# profit for G = 0.0075 , n= 200000 , scale = 25 is : 33528.0
# ...

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid'] # profit month
# fix grid size, lot size and lookback
G=0.0075
lb = 200
n=200_000
for ind_scale in np.arange(10,120,1):
    ind_scale=np.round(ind_scale,1)
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = 'a', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 10 is : 17460.0
# profit for G = 0.0075 , n= 200000 , scale = 11 is : 18510.0
# profit for G = 0.0075 , n= 200000 , scale = 12 is : 19560.0
# profit for G = 0.0075 , n= 200000 , scale = 13 is : 20460.0
# profit for G = 0.0075 , n= 200000 , scale = 14 is : 21588.0
# profit for G = 0.0075 , n= 200000 , scale = 15 is : 22638.0
# profit for G = 0.0075 , n= 200000 , scale = 16 is : 23766.0
# profit for G = 0.0075 , n= 200000 , scale = 17 is : 24894.0
# profit for G = 0.0075 , n= 200000 , scale = 18 is : 25716.0
# profit for G = 0.0075 , n= 200000 , scale = 19 is : 26766.0
# profit for G = 0.0075 , n= 200000 , scale = 20 is : 27816.0
# profit for G = 0.0075 , n= 200000 , scale = 21 is : 29022.0
# profit for G = 0.0075 , n= 200000 , scale = 22 is : 30150.0
# profit for G = 0.0075 , n= 200000 , scale = 23 is : 31272.0
# profit for G = 0.0075 , n= 200000 , scale = 24 is : 32400.0
# profit for G = 0.0075 , n= 200000 , scale = 25 is : 33528.0
# ...

# %% [markdown]
# Until scale = 100 works really well

# %%
Test_data4 = data_gather_from_files('1 june 2021','30 june 2021')['EURUSD.mid']
# fix grid size, lot size and lookback
G=0.0075
lb = 200
n=200_000
for ind_scale in np.arange(1,3.01,0.1):
    ind_scale=np.round(ind_scale,1)
    maxloss,_,profit = run_strategy_optimised(Test_data4, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 1.0 is : -15800.0
# profit for G = 0.0075 , n= 200000 , scale = 1.1 is : -15800.0
# profit for G = 0.0075 , n= 200000 , scale = 1.2 is : -15750.0
# profit for G = 0.0075 , n= 200000 , scale = 1.3 is : -15750.0
# profit for G = 0.0075 , n= 200000 , scale = 1.4 is : -15700.0
# profit for G = 0.0075 , n= 200000 , scale = 1.5 is : -15700.0
# profit for G = 0.0075 , n= 200000 , scale = 1.6 is : -15700.0
# profit for G = 0.0075 , n= 200000 , scale = 1.7 is : -15650.0
# profit for G = 0.0075 , n= 200000 , scale = 1.8 is : -15650.0
# profit for G = 0.0075 , n= 200000 , scale = 1.9 is : -15600.0
# profit for G = 0.0075 , n= 200000 , scale = 2.0 is : -15600.0
# profit for G = 0.0075 , n= 200000 , scale = 2.1 is : -15550.0
# profit for G = 0.0075 , n= 200000 , scale = 2.2 is : -15550.0
# profit for G = 0.0075 , n= 200000 , scale = 2.3 is : -15550.0
# profit for G = 0.0075 , n= 200000 , scale = 2.4 is : -15500.0
# ...

# %% [markdown]
# ?Does this mean the large scale indicator give benefits both in profit and loss year? >> true for both profit and loss year

# %%
Test_data4 = data_gather_from_files('1 june 2021','30 june 2021')['EURUSD.mid']
# fix grid size, lot size and lookback
G=0.0075
lb = 200
n=200_000
for ind_scale in np.arange(1,50,1):
    ind_scale=np.round(ind_scale,1)
    maxloss,_,profit = run_strategy_optimised(Test_data4, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 1 is : -15800.0
# profit for G = 0.0075 , n= 200000 , scale = 2 is : -15600.0
# profit for G = 0.0075 , n= 200000 , scale = 3 is : -15400.0
# profit for G = 0.0075 , n= 200000 , scale = 4 is : -15200.0
# profit for G = 0.0075 , n= 200000 , scale = 5 is : -15000.0
# profit for G = 0.0075 , n= 200000 , scale = 6 is : -14800.0
# profit for G = 0.0075 , n= 200000 , scale = 7 is : -14600.0
# profit for G = 0.0075 , n= 200000 , scale = 8 is : -14400.0
# profit for G = 0.0075 , n= 200000 , scale = 9 is : -14150.0
# profit for G = 0.0075 , n= 200000 , scale = 10 is : -13950.0
# profit for G = 0.0075 , n= 200000 , scale = 11 is : -13750.0
# profit for G = 0.0075 , n= 200000 , scale = 12 is : -13550.0
# profit for G = 0.0075 , n= 200000 , scale = 13 is : -13350.0
# profit for G = 0.0075 , n= 200000 , scale = 14 is : -13150.0
# profit for G = 0.0075 , n= 200000 , scale = 15 is : -12950.0
# profit for G = 0.0075 , n= 200000 , scale = 16 is : -12750.0
# ...

# %%
Test_data4 = data_gather_from_files('1 june 2021','30 june 2021')['EURUSD.mid']
# fix grid size, lot size and lookback
G=0.0075
lb = 200
n=200_000
for ind_scale in np.arange(1,50,1):
    ind_scale=np.round(ind_scale,1)
    maxloss,_,profit = run_strategy_optimised(Test_data4, G, n, indicator_type = 'a', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 1 is : -16000.0
# profit for G = 0.0075 , n= 200000 , scale = 2 is : -16000.0
# profit for G = 0.0075 , n= 200000 , scale = 3 is : -16000.0
# profit for G = 0.0075 , n= 200000 , scale = 4 is : -16000.0
# profit for G = 0.0075 , n= 200000 , scale = 5 is : -16000.0
# profit for G = 0.0075 , n= 200000 , scale = 6 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 7 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 8 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 9 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 10 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 11 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 12 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 13 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 14 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 15 is : -15950.0
# profit for G = 0.0075 , n= 200000 , scale = 16 is : -15950.0
# ...

# %%
Test_data4 = data_gather_from_files('1 june 2021','30 june 2021')['EURUSD.mid']
# fix grid size, lot size and lookback
G=0.0075
lb = 200
n=200_000
for ind_scale in np.arange(10,120,1):
    ind_scale=np.round(ind_scale,1)
    maxloss,_,profit = run_strategy_optimised(Test_data4, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 10 is : -13950.0
# profit for G = 0.0075 , n= 200000 , scale = 11 is : -13750.0
# profit for G = 0.0075 , n= 200000 , scale = 12 is : -13550.0
# profit for G = 0.0075 , n= 200000 , scale = 13 is : -13350.0
# profit for G = 0.0075 , n= 200000 , scale = 14 is : -13150.0
# profit for G = 0.0075 , n= 200000 , scale = 15 is : -12950.0
# profit for G = 0.0075 , n= 200000 , scale = 16 is : -12750.0
# profit for G = 0.0075 , n= 200000 , scale = 17 is : -12550.0
# profit for G = 0.0075 , n= 200000 , scale = 18 is : -12350.0
# profit for G = 0.0075 , n= 200000 , scale = 19 is : -12150.0
# profit for G = 0.0075 , n= 200000 , scale = 20 is : -11950.0
# profit for G = 0.0075 , n= 200000 , scale = 21 is : -11750.0
# profit for G = 0.0075 , n= 200000 , scale = 22 is : -11550.0
# profit for G = 0.0075 , n= 200000 , scale = 23 is : -11350.0
# profit for G = 0.0075 , n= 200000 , scale = 24 is : -11150.0
# ...

# %% [markdown]
# Its even giving a profit

# %% [markdown]
# ### next lets analyze lookback

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid'] # profit month
# fix grid size, lot size and ind_scale
G=0.0075
ind_scale =3
lb_period = [9,20,30,50,100,150,200]
n=200_000
for lb in lb_period:
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} , lookback = {lb} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 9 is : 11736.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 20 is : 10518.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 30 is : 10518.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 50 is : 10212.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 100 is : 10212.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 150 is : 9984.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 200 is : 9984.0

# %%
Test_data3 = data_gather_from_files('1 may 2021','31 may 2021')['EURUSD.mid'] # profit month
# fix grid size, lot size and ind_scale
G=0.0075
ind_scale =3
lb_period = [9,20,30,50,100,150,200]
n=200_000
for lb in lb_period:
    maxloss,_,profit = run_strategy_optimised(Test_data3, G, n, indicator_type = 'a', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} , lookback = {lb} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 9 is : 10620.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 20 is : 10248.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 30 is : 10476.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 50 is : 9720.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 100 is : 9720.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 150 is : 9720.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 200 is : 9798.0

# %%
Test_data4 = data_gather_from_files('1 june 2021','30 june 2021')['EURUSD.mid']
# fix grid size, lot size and ind_scale
G=0.0075
ind_scale =3
lb_period = [9,20,30,50,100,150,200]
n=200_000
for lb in lb_period:
    maxloss,_,profit = run_strategy_optimised(Test_data4, G, n, indicator_type = 'v', lookback = lb, indicator_scale = ind_scale)
    print(f'profit for G = {G} , n= {n} , scale = {ind_scale} , lookback = {lb} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 9 is : -15100.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 20 is : -15250.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 30 is : -15300.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 50 is : -15350.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 100 is : -15400.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 150 is : -15400.0
# profit for G = 0.0075 , n= 200000 , scale = 3 , lookback = 200 is : -15400.0

# %% [markdown]
# ?should we use short lookback? need more evaluation? >> not true

# %% [markdown]
# ### Summary Group 3
# * Should we rescale the indicator scale? > good scale indicator can convert loss to profit >> not true
# * lot size meaning is the same as in group 1

# %% [markdown]
# Test randomly for thw hypothesis

# %%
Test_data5 = data_gather_from_files('1 jan 2021','31 jan 2021')['EURUSD.mid']
# fix grid size, lot size and ind_scale
G=0.05 #totally random
lb_period = [9,20,30,50,100,150,200]
n=100_000 # keep it small
for lb in lb_period:
    maxloss,_,profit = run_strategy_optimised(Test_data5, G, n, indicator_type = 'v', lookback = lb, indicator_scale = 100)
    print(f'profit for G = {G} , n= {n} , lookback = {lb} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.05 , n= 100000 , lookback = 9 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 20 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 30 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 50 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 100 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 150 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 200 is : 1340.0

# %%
Test_data5 = data_gather_from_files('1 jan 2021','31 jan 2021')['EURUSD.mid']
# fix grid size, lot size and ind_scale
G=0.05 #totally random
lb_period = [9,20,30,50,100,150,200]
n=100_000 # keep it small
for lb in lb_period:
    maxloss,_,profit = run_strategy_optimised(Test_data5, G, n, indicator_type = 'v', lookback = lb, indicator_scale = 1.5)
    print(f'profit for G = {G} , n= {n} , lookback = {lb} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.05 , n= 100000 , lookback = 9 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 20 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 30 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 50 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 100 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 150 is : 1340.0
# profit for G = 0.05 , n= 100000 , lookback = 200 is : 1340.0

# %%
Test_data5 = data_gather_from_files('1 jan 2021','31 jan 2021')['EURUSD.mid']
# fix grid size, lot size and ind_scale
G=0.0045 #totally random
lb_period = [9,20,30,50,100,150,200]
n=100_000 # keep it small
for lb in lb_period:
    maxloss,_,profit = run_strategy_optimised(Test_data5, G, n, indicator_type = 'v', lookback = lb, indicator_scale = 1.5)
    print(f'profit for G = {G} , n= {n} , lookback = {lb} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0045 , n= 100000 , lookback = 9 is : 2199.0
# profit for G = 0.0045 , n= 100000 , lookback = 20 is : 1939.0
# profit for G = 0.0045 , n= 100000 , lookback = 30 is : 2090.0
# profit for G = 0.0045 , n= 100000 , lookback = 50 is : 2087.0
# profit for G = 0.0045 , n= 100000 , lookback = 100 is : 2071.0
# profit for G = 0.0045 , n= 100000 , lookback = 150 is : 2222.0
# profit for G = 0.0045 , n= 100000 , lookback = 200 is : 2222.0

# %%
Test_data5 = data_gather_from_files('1 jan 2021','31 jan 2021')['EURUSD.mid']
# fix grid size, lot size and ind_scale
G=0.0045 #totally random
lb_period = [9,20,30,50,100,150,200]
n=100_000 # keep it small
for lb in lb_period:
    maxloss,_,profit = run_strategy_optimised(Test_data5, G, n, indicator_type = 'v', lookback = lb, indicator_scale = 10)
    print(f'profit for G = {G} , n= {n} , lookback = {lb} is : {profit}')
    #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0045 , n= 100000 , lookback = 9 is : -5068.0
# profit for G = 0.0045 , n= 100000 , lookback = 20 is : -4610.0
# profit for G = 0.0045 , n= 100000 , lookback = 30 is : -4606.0
# profit for G = 0.0045 , n= 100000 , lookback = 50 is : -4345.0
# profit for G = 0.0045 , n= 100000 , lookback = 100 is : -4428.0
# profit for G = 0.0045 , n= 100000 , lookback = 150 is : -4476.0
# profit for G = 0.0045 , n= 100000 , lookback = 200 is : -4463.0

# %% [markdown]
# High indicator scale is also bad

# %%
Test_data5 = data_gather_from_files('1 jan 2021','31 jan 2021')['EURUSD.mid']
# fix grid size, lot size and ind_scale
G=0.0045 #totally random
lb_period = [9,20,30,50,100,150,200]
for lb in lb_period:
    for n in range(100000,2100000,100000):
        maxloss,_,profit = run_strategy_optimised(Test_data5, G, n, indicator_type = 'v', lookback = lb, indicator_scale = 1.5)
        print(f'profit for G = {G} , n= {n} , lookback = {lb} is : {profit}')
        #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0045 , n= 100000 , lookback = 9 is : 2199.0
# profit for G = 0.0045 , n= 200000 , lookback = 9 is : 4398.0
# profit for G = 0.0045 , n= 300000 , lookback = 9 is : 6597.0
# profit for G = 0.0045 , n= 400000 , lookback = 9 is : 8796.0
# profit for G = 0.0045 , n= 500000 , lookback = 9 is : 10995.0
# profit for G = 0.0045 , n= 600000 , lookback = 9 is : 13194.0
# profit for G = 0.0045 , n= 700000 , lookback = 9 is : 15393.0
# profit for G = 0.0045 , n= 800000 , lookback = 9 is : 17592.0
# profit for G = 0.0045 , n= 900000 , lookback = 9 is : 19791.0
# profit for G = 0.0045 , n= 1000000 , lookback = 9 is : 21990.0
# profit for G = 0.0045 , n= 1100000 , lookback = 9 is : 24189.0
# profit for G = 0.0045 , n= 1200000 , lookback = 9 is : 26388.0
# profit for G = 0.0045 , n= 1300000 , lookback = 9 is : 28587.0
# profit for G = 0.0045 , n= 1400000 , lookback = 9 is : 30786.0
# profit for G = 0.0045 , n= 1500000 , lookback = 9 is : 32985.0
# ...

# %%
Test_data5 = data_gather_from_files('1 jan 2021','31 jan 2021')['EURUSD.mid']
# fix grid size, lot size and ind_scale
G=0.0045 #totally random
lb_period = [9,20,30,50,100,150,200]
for lb in lb_period:
    for n in range(100000,2000000,100000):
        maxloss,_,profit = run_strategy_optimised(Test_data5, G, n, indicator_type = 'v', lookback = lb, indicator_scale = 10)
        print(f'profit for G = {G} , n= {n} , lookback = {lb} is : {profit}')
        #print(f'max loss for G = {G} , n= {n} is : {maxloss}')
# Out:
# profit for G = 0.0045 , n= 100000 , lookback = 9 is : -5068.0
# profit for G = 0.0045 , n= 200000 , lookback = 9 is : -10136.0
# profit for G = 0.0045 , n= 300000 , lookback = 9 is : -15204.0
# profit for G = 0.0045 , n= 400000 , lookback = 9 is : -20272.0
# profit for G = 0.0045 , n= 500000 , lookback = 9 is : -25340.0
# profit for G = 0.0045 , n= 600000 , lookback = 9 is : -30408.0
# profit for G = 0.0045 , n= 700000 , lookback = 9 is : -35476.0
# profit for G = 0.0045 , n= 800000 , lookback = 9 is : -40544.0
# profit for G = 0.0045 , n= 900000 , lookback = 9 is : -45612.0
# profit for G = 0.0045 , n= 1000000 , lookback = 9 is : -51480.0
# profit for G = 0.0045 , n= 1100000 , lookback = 9 is : -35156.0
# profit for G = 0.0045 , n= 1200000 , lookback = 9 is : -38352.0
# profit for G = 0.0045 , n= 1300000 , lookback = 9 is : -33384.0
# profit for G = 0.0045 , n= 1400000 , lookback = 9 is : -36848.0
# profit for G = 0.0045 , n= 1500000 , lookback = 9 is : 5550.0
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# lot size tends to scale both profit and loss however some lots size behave differently
