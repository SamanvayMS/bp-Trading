# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
import pandas as pd
from bp import data_gather_from_files,run_strategy_optimised,run_strategy_eval
import time
from datetime import datetime
from dateutil.relativedelta import relativedelta
from GA_optimiser import *

# %% [markdown]
# If import GA_optimiser error (line 53) then change Grid_Search to None

# %% [markdown]
# ## Minimising loss by U_PNL vol

# %% [markdown]
# ## Group 1 : Deap optimiser with basic strategy

# %%
def deap_optimiser_g_n_std(train_data, test_data, parameters, optimization_params):
    """
    Optimizes the parameters of a trading strategy using a genetic algorithm.
    
    Args:
    train_data (pandas.DataFrame): The training data used to optimize the strategy.
    test_data (pandas.DataFrame): The test data used to evaluate the optimized strategy.
    parameters (list): A list of two lists, where the first list contains the grid parameters and the second list contains the position parameters.
    optimization_params (list): A list of three parameters: the number of generations, the number of population, and the maximum number of stagnant generations before early stopping.
    
    Returns:
    tuple: A tuple containing the maximum loss, the return per unit of risk, the profit, and the optimal values of G and n.
    """
    ngen = optimization_params[0]  # number of generations
    npop = optimization_params[1]  # number of population

    error_check(parameters,2)
    
    grid_params = parameters[0]
    position_params = parameters[1]

    creator.create("FitnessMax", base.Fitness, weights=(1.0,)) #maximizing
    creator.create("Individual", list, fitness=creator.FitnessMax)

    toolbox = base.Toolbox()

    # Define the genes for our individual
    toolbox.register("G_gene", random.randint, grid_params[0]//grid_params[2], grid_params[1]//grid_params[2])
    toolbox.register("n_gene", random.randint, position_params[0]//position_params[2], position_params[1]//position_params[2])

    # Create an individual with the genes
    toolbox.register("individual", tools.initCycle, creator.Individual, (toolbox.G_gene, toolbox.n_gene), n=1)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    def objective(individual):
        G, n = individual[0]*grid_params[2], individual[1]*position_params[2]
        max_loss, R_PNL, profit, std = run_strategy_optimised(train_data, G, n)
    
        constraints = [
            max_loss < -500e3
        ]

        if any(constraints):
            return float('-inf'),  # Return large negative value when constraints are not satisfied
        return profit/std,

    toolbox.register("mate", tools.cxTwoPoint)
    toolbox.register("mutate", tools.mutUniformInt, low=[grid_params[0]//grid_params[2], position_params[0]//position_params[2]], 
                     up=[grid_params[1]//grid_params[2], position_params[1]//position_params[2]], indpb=0.2)
    toolbox.register("select", tools.selTournament, tournsize=3)   ##############
    toolbox.register("evaluate", objective)

    population = toolbox.population(n=npop)
    CXPB, MUTPB = 0.5, 0.2

    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit

    #initiate early stopping
    stagnant_generations = 0  # Counter for generations without improvement
    MAX_STAGNANT_GEN = optimization_params[2]  # Early stopping criterion: stop if no improvement over x generations
    best_fitness_so_far = float('-inf')  # since we're maximizing
    ##
    for gen in range(ngen):
        offspring = toolbox.select(population, len(population))
        offspring = list(map(toolbox.clone, offspring))
        
        # Crossover
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CXPB:
                toolbox.mate(child1, child2)
                del child1.fitness.values
                del child2.fitness.values
        
        # Mutation
        for mutant in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        fitnesses = list(map(toolbox.evaluate, offspring))
        for ind, fit in zip(offspring, fitnesses):
            ind.fitness.values = fit

        #early stopping
        current_best_fitness = max(ind.fitness.values[0] for ind in population)

        if current_best_fitness > best_fitness_so_far:
            best_fitness_so_far = current_best_fitness
            stagnant_generations = 0  # Reset counter
        else:
            stagnant_generations += 1

        if stagnant_generations >= MAX_STAGNANT_GEN:
            print(f"Early stopping on generation {gen} due to no improvement.")
            break
        ##
        population[:] = offspring

    best_ind = tools.selBest(population, 1)[0]
    optimal_g = np.round(best_ind[0]*grid_params[2],5)
    optimal_n = best_ind[1]*position_params[2]
    print("optimisation completed")
    max_loss, R_PNL,profit,std  = run_strategy_optimised(test_data, optimal_g,optimal_n)
    return max_loss, R_PNL,profit,[optimal_g,optimal_n]

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])

print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params))

# Adjust these parameter according to search space
n_trials = 10 #NGEN
npop = 100
early_stopping_gen = 10 # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters = [grid_params,lot_params]

results0 = walk_forward_analysis('jan 2022','jan 2023',1,parameters,optimization_function=deap_optimiser_g_n_std,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
results0
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# total_number_of_combinations:- 342.0
# Data gathered for training period:  01 Jan 2021 31 Dec 2021
# Data gathered for testing period:  01 Jan 2022 31 Jan 2022
# optimisation completed
# Optimal parameters are:  [0.001, 1300000]
# Max loss,R_PNL,profit are:  -123500.0 -97262.2428 -96460.0
# Data gathered for training period:  01 Feb 2021 31 Jan 2022
# Data gathered for testing period:  01 Feb 2022 28 Feb 2022
# optimisation completed
# Optimal parameters are:  [0.009, 2000000]
# Max loss,R_PNL,profit are:  -54000.0 72000.0 72000.0
# Data gathered for training period:  01 Mar 2021 28 Feb 2022
# Data gathered for testing period:  01 Mar 2022 31 Mar 2022
# optimisation completed
# Optimal parameters are:  [0.0045, 1400000]
# Max loss,R_PNL,profit are:  -198037.5 -74487.5 -135877.5
# Data gathered for training period:  01 Apr 2021 31 Mar 2022
# Data gathered for testing period:  01 Apr 2022 30 Apr 2022
# optimisation completed
# Optimal parameters are:  [0.0025, 400000]
# Max loss,R_PNL,profit are:  -160143.4734 -150903.4734 -150903.4734
# Data gathered for training period:  01 May 2021 30 Apr 2022
# Data gathered for testing period:  01 May 2022 31 May 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1700000]
# Max loss,R_PNL,profit are:  0 126854.0 77350.0
# Data gathered for training period:  01 Jun 2021 31 May 2022
# Data gathered for testing period:  01 Jun 2022 30 Jun 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1700000]
# Max loss,R_PNL,profit are:  -124950.0 65450.0 53040.0
# Data gathered for training period:  01 Jul 2021 30 Jun 2022
# Data gathered for testing period:  01 Jul 2022 31 Jul 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1500000]
# Max loss,R_PNL,profit are:  -176250.0 86250.0 85350.0
# Data gathered for training period:  01 Aug 2021 31 Jul 2022
# Data gathered for testing period:  01 Aug 2022 31 Aug 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -78599.9999 -10599.9999 -18759.9999
# Data gathered for training period:  01 Sep 2021 31 Aug 2022
# Data gathered for testing period:  01 Sep 2022 30 Sep 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1500000]
# Max loss,R_PNL,profit are:  -38700.0 49350.0001 13050.0
# Data gathered for training period:  01 Oct 2021 30 Sep 2022
# Data gathered for testing period:  01 Oct 2022 31 Oct 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -54400.0 111009.9999 110500.0
# Data gathered for training period:  01 Nov 2021 31 Oct 2022
# Data gathered for testing period:  01 Nov 2022 30 Nov 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -142633.3334 30993.3333 47086.6666
# Data gathered for training period:  01 Dec 2021 30 Nov 2022
# Data gathered for testing period:  01 Dec 2022 31 Dec 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -81600.0 36264.1483 2040.0
#                             max_loss        R_PNL       profit
# 01 Jan 2022-31 Jan 2022 -123500.0000  -97262.2428  -96460.0000
# 01 Feb 2022-28 Feb 2022  -54000.0000   72000.0000   72000.0000
# 01 Mar 2022-31 Mar 2022 -198037.5000  -74487.5000 -135877.5000
# 01 Apr 2022-30 Apr 2022 -160143.4734 -150903.4734 -150903.4734
# 01 May 2022-31 May 2022       0.0000  126854.0000   77350.0000
# 01 Jun 2022-30 Jun 2022 -124950.0000   65450.0000   53040.0000
# 01 Jul 2022-31 Jul 2022 -176250.0000   86250.0000   85350.0000
# 01 Aug 2022-31 Aug 2022  -78599.9999  -10599.9999  -18759.9999
# 01 Sep 2022-30 Sep 2022  -38700.0000   49350.0001   13050.0000
# 01 Oct 2022-31 Oct 2022  -54400.0000  111009.9999  110500.0000
# 01 Nov 2022-30 Nov 2022 -142633.3334   30993.3333   47086.6666
# 01 Dec 2022-31 Dec 2022  -81600.0000   36264.1483    2040.0000

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])

print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params))

# Adjust these parameter according to search space
n_trials = 10 #NGEN
npop = 100
early_stopping_gen = 10 # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters = [grid_params,lot_params]

results0 = walk_forward_analysis('jan 2022','jan 2023',1,parameters,optimization_function=deap_optimiser_g_n,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
results0
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# total_number_of_combinations:- 342.0
# Data gathered for training period:  01 Jan 2021 31 Dec 2021
# Data gathered for testing period:  01 Jan 2022 31 Jan 2022
# optimisation completed
# Optimal parameters are:  [0.0015, 2000000]
# Max loss,R_PNL,profit are:  -129000.0 -98105.6422 -103800.0
# Data gathered for training period:  01 Feb 2021 31 Jan 2022
# Data gathered for testing period:  01 Feb 2022 28 Feb 2022
# optimisation completed
# Optimal parameters are:  [0.009, 2000000]
# Max loss,R_PNL,profit are:  -54000.0 72000.0 72000.0
# Data gathered for training period:  01 Mar 2021 28 Feb 2022
# Data gathered for testing period:  01 Mar 2022 31 Mar 2022
# optimisation completed
# Optimal parameters are:  [0.007, 2000000]
# Max loss,R_PNL,profit are:  -192000.0 -115000.0 -188800.0
# Data gathered for training period:  01 Apr 2021 31 Mar 2022
# Data gathered for testing period:  01 Apr 2022 30 Apr 2022
# optimisation completed
# Optimal parameters are:  [0.009, 1600000]
# Max loss,R_PNL,profit are:  -157200.0 -154960.0 -154960.0
# Data gathered for training period:  01 May 2021 30 Apr 2022
# Data gathered for testing period:  01 May 2022 31 May 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1700000]
# Max loss,R_PNL,profit are:  0 126854.0 77350.0
# Data gathered for training period:  01 Jun 2021 31 May 2022
# Data gathered for testing period:  01 Jun 2022 30 Jun 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1700000]
# Max loss,R_PNL,profit are:  -124950.0 65450.0 53040.0
# Data gathered for training period:  01 Jul 2021 30 Jun 2022
# Data gathered for testing period:  01 Jul 2022 31 Jul 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1500000]
# Max loss,R_PNL,profit are:  -176250.0 86250.0 85350.0
# Data gathered for training period:  01 Aug 2021 31 Jul 2022
# Data gathered for testing period:  01 Aug 2022 31 Aug 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1500000]
# Max loss,R_PNL,profit are:  -57750.0 62265.0 69300.0
# Data gathered for training period:  01 Sep 2021 31 Aug 2022
# Data gathered for testing period:  01 Sep 2022 30 Sep 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -25049.9999 66070.0 43630.0001
# Data gathered for training period:  01 Oct 2021 30 Sep 2022
# Data gathered for testing period:  01 Oct 2022 31 Oct 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -54400.0 111009.9999 110500.0
# Data gathered for training period:  01 Nov 2021 31 Oct 2022
# Data gathered for testing period:  01 Nov 2022 30 Nov 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -142633.3334 30993.3333 47086.6666
# Data gathered for training period:  01 Dec 2021 30 Nov 2022
# Data gathered for testing period:  01 Dec 2022 31 Dec 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -81600.0 36264.1483 2040.0
#                             max_loss        R_PNL       profit
# 01 Jan 2022-31 Jan 2022 -129000.0000  -98105.6422 -103800.0000
# 01 Feb 2022-28 Feb 2022  -54000.0000   72000.0000   72000.0000
# 01 Mar 2022-31 Mar 2022 -192000.0000 -115000.0000 -188800.0000
# 01 Apr 2022-30 Apr 2022 -157200.0000 -154960.0000 -154960.0000
# 01 May 2022-31 May 2022       0.0000  126854.0000   77350.0000
# 01 Jun 2022-30 Jun 2022 -124950.0000   65450.0000   53040.0000
# 01 Jul 2022-31 Jul 2022 -176250.0000   86250.0000   85350.0000
# 01 Aug 2022-31 Aug 2022  -57750.0000   62265.0000   69300.0000
# 01 Sep 2022-30 Sep 2022  -25049.9999   66070.0000   43630.0001
# 01 Oct 2022-31 Oct 2022  -54400.0000  111009.9999  110500.0000
# 01 Nov 2022-30 Nov 2022 -142633.3334   30993.3333   47086.6666
# 01 Dec 2022-31 Dec 2022  -81600.0000   36264.1483    2040.0000

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])

print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params))

# Adjust these parameter according to search space
n_trials = 10 #NGEN
npop = 100
early_stopping_gen = 10 # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters = [grid_params,lot_params]

results0 = walk_forward_analysis('jan 2018','jan 2023',1,parameters,optimization_function=deap_optimiser_g_n_std,optimizer_params=optimizer_param,lookback_in_months=3,evaluation_period=1)
results0
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# total_number_of_combinations:- 342.0
# Data gathered for training period:  01 Oct 2017 31 Dec 2017
# Data gathered for testing period:  01 Jan 2018 31 Jan 2018
# optimisation completed
# Optimal parameters are:  [0.0075, 1300000]
# Max loss,R_PNL,profit are:  -107250.0 9360.0 -2600.0
# Data gathered for training period:  01 Nov 2017 31 Jan 2018
# Data gathered for testing period:  01 Feb 2018 28 Feb 2018
# optimisation completed
# Optimal parameters are:  [0.0025, 1900000]
# Max loss,R_PNL,profit are:  -47500.0 709.7165 -42180.0
# Data gathered for training period:  01 Dec 2017 28 Feb 2018
# Data gathered for testing period:  01 Mar 2018 31 Mar 2018
# optimisation completed
# Optimal parameters are:  [0.004, 1300000]
# Max loss,R_PNL,profit are:  -93600.0 24960.0 40430.0
# Data gathered for training period:  01 Jan 2018 31 Mar 2018
# Data gathered for testing period:  01 Apr 2018 30 Apr 2018
# optimisation completed
# Optimal parameters are:  [0.001, 500000]
# Max loss,R_PNL,profit are:  -52500.0 -4438.2784 -8000.0
# Data gathered for training period:  01 Feb 2018 30 Apr 2018
# Data gathered for testing period:  01 May 2018 31 May 2018
# optimisation completed
# Optimal parameters are:  [0.001, 400000]
# Max loss,R_PNL,profit are:  -278000.0 -191498.1439 -182400.0
# Data gathered for training period:  01 Mar 2018 31 May 2018
# Data gathered for testing period:  01 Jun 2018 30 Jun 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1700000]
# Max loss,R_PNL,profit are:  -9350.0 112200.0001 112200.0
# Data gathered for training period:  01 Apr 2018 30 Jun 2018
# Data gathered for testing period:  01 Jul 2018 31 Jul 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 2000000]
# Max loss,R_PNL,profit are:  -9000.0 117000.0 115600.0
# Data gathered for training period:  01 May 2018 31 Jul 2018
# Data gathered for testing period:  01 Aug 2018 31 Aug 2018
# optimisation completed
# Optimal parameters are:  [0.002, 1700000]
# Max loss,R_PNL,profit are:  -285600.0 -234517.1758 -236640.0
# Data gathered for training period:  01 Jun 2018 31 Aug 2018
# Data gathered for testing period:  01 Sep 2018 30 Sep 2018
# optimisation completed
# Optimal parameters are:  [0.01, 1700000]
# Max loss,R_PNL,profit are:  -51000.0 17000.0 33320.0
# Data gathered for training period:  01 Jul 2018 30 Sep 2018
# Data gathered for testing period:  01 Oct 2018 31 Oct 2018
# optimisation completed
# Optimal parameters are:  [0.01, 1500000]
# Max loss,R_PNL,profit are:  -54750.0 7500.0 -54750.0
# Data gathered for training period:  01 Aug 2018 31 Oct 2018
# Data gathered for testing period:  01 Nov 2018 30 Nov 2018
# optimisation completed
# Optimal parameters are:  [0.01, 1100000]
# Max loss,R_PNL,profit are:  0 33000.0 33000.0
# Data gathered for training period:  01 Sep 2018 30 Nov 2018
# Data gathered for testing period:  01 Dec 2018 31 Dec 2018
# optimisation completed
# Optimal parameters are:  [0.0015, 1300000]
# Max loss,R_PNL,profit are:  -5850.0 162810.9599 166920.0
# Data gathered for training period:  01 Oct 2018 31 Dec 2018
# Data gathered for testing period:  01 Jan 2019 31 Jan 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1300000]
# Max loss,R_PNL,profit are:  -74100.0 -23083.1247 -49530.0
# Data gathered for training period:  01 Nov 2018 31 Jan 2019
# Data gathered for testing period:  01 Feb 2019 28 Feb 2019
# optimisation completed
# Optimal parameters are:  [0.01, 700000]
# Max loss,R_PNL,profit are:  -7000.0 3500.0 5600.0
# Data gathered for training period:  01 Dec 2018 28 Feb 2019
# Data gathered for testing period:  01 Mar 2019 31 Mar 2019
# optimisation completed
# Optimal parameters are:  [0.0095, 1700000]
# Max loss,R_PNL,profit are:  0 49810.0 49810.0
# Data gathered for training period:  01 Jan 2019 31 Mar 2019
# Data gathered for testing period:  01 Apr 2019 30 Apr 2019
# optimisation completed
# Optimal parameters are:  [0.01, 100000]
# Max loss,R_PNL,profit are:  0 1000.0 850.0
# Data gathered for training period:  01 Feb 2019 30 Apr 2019
# Data gathered for testing period:  01 May 2019 31 May 2019
# optimisation completed
# Optimal parameters are:  [0.0095, 100000]
# Max loss,R_PNL,profit are:  -950.0 475.0 150.0
# Data gathered for training period:  01 Mar 2019 31 May 2019
# Data gathered for testing period:  01 Jun 2019 30 Jun 2019
# optimisation completed
# Optimal parameters are:  [0.01, 900000]
# Max loss,R_PNL,profit are:  -18000.0 -480.0 -10440.0
# Data gathered for training period:  01 Apr 2019 30 Jun 2019
# Data gathered for testing period:  01 Jul 2019 31 Jul 2019
# optimisation completed
# Optimal parameters are:  [0.01, 1900000]
# Max loss,R_PNL,profit are:  0 19000.0 10830.0
# Data gathered for training period:  01 May 2019 31 Jul 2019
# Data gathered for testing period:  01 Aug 2019 31 Aug 2019
# optimisation completed
# Optimal parameters are:  [0.005, 1100000]
# Max loss,R_PNL,profit are:  0 22000.0 14520.0
# Data gathered for training period:  01 Jun 2019 31 Aug 2019
# Data gathered for testing period:  01 Sep 2019 30 Sep 2019
# optimisation completed
# Optimal parameters are:  [0.008, 100000]
# Max loss,R_PNL,profit are:  0 1600.0 1420.0
# Data gathered for training period:  01 Jul 2019 30 Sep 2019
# Data gathered for testing period:  01 Oct 2019 31 Oct 2019
# optimisation completed
# Optimal parameters are:  [0.002, 1700000]
# Max loss,R_PNL,profit are:  -146200.0 -86853.7299 -110160.0
# Data gathered for training period:  01 Aug 2019 31 Oct 2019
# Data gathered for testing period:  01 Nov 2019 30 Nov 2019
# optimisation completed
# Optimal parameters are:  [0.0075, 300000]
# Max loss,R_PNL,profit are:  0 2250.0 2040.0
# Data gathered for training period:  01 Sep 2019 30 Nov 2019
# Data gathered for testing period:  01 Dec 2019 31 Dec 2019
# optimisation completed
# Optimal parameters are:  [0.007, 500000]
# Max loss,R_PNL,profit are:  -100.0 3500.0 -100.0
# Data gathered for training period:  01 Oct 2019 31 Dec 2019
# Data gathered for testing period:  01 Jan 2020 31 Jan 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 1900000]
# Max loss,R_PNL,profit are:  -57000.0 -30974.0823 -35530.0
# Data gathered for training period:  01 Nov 2019 31 Jan 2020
# Data gathered for testing period:  01 Feb 2020 29 Feb 2020
# optimisation completed
# Optimal parameters are:  [0.01, 1800000]
# Max loss,R_PNL,profit are:  0 54000.0 54000.0
# Data gathered for training period:  01 Dec 2019 29 Feb 2020
# Data gathered for testing period:  01 Mar 2020 31 Mar 2020
# optimisation completed
# Optimal parameters are:  [0.0065, 700000]
# Max loss,R_PNL,profit are:  -86450.0 124319.9997 124320.0
# Data gathered for training period:  01 Jan 2020 31 Mar 2020
# Data gathered for testing period:  01 Apr 2020 30 Apr 2020
# optimisation completed
# Optimal parameters are:  [0.0085, 100000]
# Max loss,R_PNL,profit are:  0 2975.0 3370.0
# Data gathered for training period:  01 Feb 2020 30 Apr 2020
# Data gathered for testing period:  01 May 2020 31 May 2020
# optimisation completed
# Optimal parameters are:  [0.001, 100000]
# Max loss,R_PNL,profit are:  -11000.0 12749.7289 11250.0
# Data gathered for training period:  01 Mar 2020 31 May 2020
# Data gathered for testing period:  01 Jun 2020 30 Jun 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 200000]
# Max loss,R_PNL,profit are:  -34800.0 40015.6892 40680.0
# Data gathered for training period:  01 Apr 2020 30 Jun 2020
# Data gathered for testing period:  01 Jul 2020 31 Jul 2020
# optimisation completed
# Optimal parameters are:  [0.0035, 100000]
# Max loss,R_PNL,profit are:  -55230.0 -10428.2007 -55230.0
# Data gathered for training period:  01 May 2020 31 Jul 2020
# Data gathered for testing period:  01 Aug 2020 31 Aug 2020
# optimisation completed
# Optimal parameters are:  [0.0035, 1900000]
# Max loss,R_PNL,profit are:  0 206149.9999 176510.0
# Data gathered for training period:  01 Jun 2020 31 Aug 2020
# Data gathered for testing period:  01 Sep 2020 30 Sep 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 1300000]
# Max loss,R_PNL,profit are:  -39000.0 59864.9999 59280.0
# Data gathered for training period:  01 Jul 2020 30 Sep 2020
# Data gathered for testing period:  01 Oct 2020 31 Oct 2020
# optimisation completed
# Optimal parameters are:  [0.007, 2000000]
# Max loss,R_PNL,profit are:  0 56000.0 47400.0
# Data gathered for training period:  01 Aug 2020 31 Oct 2020
# Data gathered for testing period:  01 Nov 2020 30 Nov 2020
# optimisation completed
# Optimal parameters are:  [0.0035, 100000]
# Max loss,R_PNL,profit are:  -10000.0 -397.6192 -10000.0
# Data gathered for training period:  01 Sep 2020 30 Nov 2020
# Data gathered for testing period:  01 Dec 2020 31 Dec 2020
# optimisation completed
# Optimal parameters are:  [0.0095, 1100000]
# Max loss,R_PNL,profit are:  -52250.0 -1959.375 -50710.0
# Data gathered for training period:  01 Oct 2020 31 Dec 2020
# Data gathered for testing period:  01 Jan 2021 31 Jan 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1700000]
# Max loss,R_PNL,profit are:  -33150.0 89419.9997 89420.0
# Data gathered for training period:  01 Nov 2020 31 Jan 2021
# Data gathered for testing period:  01 Feb 2021 28 Feb 2021
# optimisation completed
# Optimal parameters are:  [0.001, 1200000]
# Max loss,R_PNL,profit are:  -91200.0 -66149.9999 -89040.0
# Data gathered for training period:  01 Dec 2020 28 Feb 2021
# Data gathered for testing period:  01 Mar 2021 31 Mar 2021
# optimisation completed
# Optimal parameters are:  [0.008, 100000]
# Max loss,R_PNL,profit are:  -8250.0 100.0 -8250.0
# Data gathered for training period:  01 Jan 2021 31 Mar 2021
# Data gathered for testing period:  01 Apr 2021 30 Apr 2021
# optimisation completed
# Optimal parameters are:  [0.005, 2000000]
# Max loss,R_PNL,profit are:  -150000.0 -130000.0 -135000.0
# Data gathered for training period:  01 Feb 2021 30 Apr 2021
# Data gathered for testing period:  01 May 2021 31 May 2021
# optimisation completed
# Optimal parameters are:  [0.009, 900000]
# Max loss,R_PNL,profit are:  -16200.0 5400.0 1080.0
# Data gathered for training period:  01 Mar 2021 31 May 2021
# Data gathered for testing period:  01 Jun 2021 30 Jun 2021
# optimisation completed
# Optimal parameters are:  [0.01, 1700000]
# Max loss,R_PNL,profit are:  -102000.0 0 -102000.0
# Data gathered for training period:  01 Apr 2021 30 Jun 2021
# Data gathered for testing period:  01 Jul 2021 31 Jul 2021
# optimisation completed
# Optimal parameters are:  [0.01, 1100000]
# Max loss,R_PNL,profit are:  0 14300.0 14300.0
# Data gathered for training period:  01 May 2021 31 Jul 2021
# Data gathered for testing period:  01 Aug 2021 31 Aug 2021
# optimisation completed
# Optimal parameters are:  [0.001, 1500000]
# Max loss,R_PNL,profit are:  -64500.0 -12181.0796 -20250.0
# Data gathered for training period:  01 Jun 2021 31 Aug 2021
# Data gathered for testing period:  01 Sep 2021 30 Sep 2021
# optimisation completed
# Optimal parameters are:  [0.001, 1200000]
# Max loss,R_PNL,profit are:  -57600.0 -7718.4271 -46560.0
# Data gathered for training period:  01 Jul 2021 30 Sep 2021
# Data gathered for testing period:  01 Oct 2021 31 Oct 2021
# optimisation completed
# Optimal parameters are:  [0.001, 1800000]
# Max loss,R_PNL,profit are:  -25200.0 64631.25 51480.0
# Data gathered for training period:  01 Aug 2021 31 Oct 2021
# Data gathered for testing period:  01 Nov 2021 30 Nov 2021
# optimisation completed
# Optimal parameters are:  [0.0095, 1900000]
# Max loss,R_PNL,profit are:  -36100.0 18050.0 13490.0
# Data gathered for training period:  01 Sep 2021 30 Nov 2021
# Data gathered for testing period:  01 Dec 2021 31 Dec 2021
# optimisation completed
# Optimal parameters are:  [0.001, 1800000]
# Max loss,R_PNL,profit are:  0 117000.0001 117000.0
# Data gathered for training period:  01 Oct 2021 31 Dec 2021
# Data gathered for testing period:  01 Jan 2022 31 Jan 2022
# optimisation completed
# Optimal parameters are:  [0.001, 1300000]
# Max loss,R_PNL,profit are:  -123500.0 -97262.2428 -96460.0
# Data gathered for training period:  01 Nov 2021 31 Jan 2022
# Data gathered for testing period:  01 Feb 2022 28 Feb 2022
# optimisation completed
# Optimal parameters are:  [0.0015, 2000000]
# Max loss,R_PNL,profit are:  -138000.0 -50000.0 -50000.0
# Data gathered for training period:  01 Dec 2021 28 Feb 2022
# Data gathered for testing period:  01 Mar 2022 31 Mar 2022
# optimisation completed
# Optimal parameters are:  [0.009, 1100000]
# Max loss,R_PNL,profit are:  -19800.0 59400.0 59400.0
# Data gathered for training period:  01 Jan 2022 31 Mar 2022
# Data gathered for testing period:  01 Apr 2022 30 Apr 2022
# optimisation completed
# Optimal parameters are:  [0.0085, 700000]
# Max loss,R_PNL,profit are:  -119000.0 -19270.0 -117040.0
# Data gathered for training period:  01 Feb 2022 30 Apr 2022
# Data gathered for testing period:  01 May 2022 31 May 2022
# optimisation completed
# Optimal parameters are:  [0.003, 1100000]
# Max loss,R_PNL,profit are:  0 108526.7053 50160.0
# Data gathered for training period:  01 Mar 2022 31 May 2022
# Data gathered for testing period:  01 Jun 2022 30 Jun 2022
# optimisation completed
# Optimal parameters are:  [0.006, 1800000]
# Max loss,R_PNL,profit are:  -64800.0 67140.0 47520.0
# Data gathered for training period:  01 Apr 2022 30 Jun 2022
# Data gathered for testing period:  01 Jul 2022 31 Jul 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1600000]
# Max loss,R_PNL,profit are:  -137200.0 52666.6668 46480.0
# Data gathered for training period:  01 May 2022 31 Jul 2022
# Data gathered for testing period:  01 Aug 2022 31 Aug 2022
# optimisation completed
# Optimal parameters are:  [0.003, 1100000]
# Max loss,R_PNL,profit are:  -89100.0 35289.267 48840.0
# Data gathered for training period:  01 Jun 2022 31 Aug 2022
# Data gathered for testing period:  01 Sep 2022 30 Sep 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1500000]
# Max loss,R_PNL,profit are:  -27750.0001 29099.9999 -7500.0001
# Data gathered for training period:  01 Jul 2022 30 Sep 2022
# Data gathered for testing period:  01 Oct 2022 31 Oct 2022
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000]
# Max loss,R_PNL,profit are:  0 165000.0 176000.0
# Data gathered for training period:  01 Aug 2022 31 Oct 2022
# Data gathered for testing period:  01 Nov 2022 30 Nov 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1700000]
# Max loss,R_PNL,profit are:  -137330.784 59189.2161 59189.216
# Data gathered for training period:  01 Sep 2022 30 Nov 2022
# Data gathered for testing period:  01 Dec 2022 31 Dec 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 2000000]
# Max loss,R_PNL,profit are:  -91000.0 9377.5856 -11600.0
#                             max_loss        R_PNL       profit
# 01 Jan 2018-31 Jan 2018 -107250.0000    9360.0000   -2600.0000
# 01 Feb 2018-28 Feb 2018  -47500.0000     709.7165  -42180.0000
# 01 Mar 2018-31 Mar 2018  -93600.0000   24960.0000   40430.0000
# 01 Apr 2018-30 Apr 2018  -52500.0000   -4438.2784   -8000.0000
# 01 May 2018-31 May 2018 -278000.0000 -191498.1439 -182400.0000
# 01 Jun 2018-30 Jun 2018   -9350.0000  112200.0001  112200.0000
# 01 Jul 2018-31 Jul 2018   -9000.0000  117000.0000  115600.0000
# 01 Aug 2018-31 Aug 2018 -285600.0000 -234517.1758 -236640.0000
# 01 Sep 2018-30 Sep 2018  -51000.0000   17000.0000   33320.0000
# 01 Oct 2018-31 Oct 2018  -54750.0000    7500.0000  -54750.0000
# 01 Nov 2018-30 Nov 2018       0.0000   33000.0000   33000.0000
# 01 Dec 2018-31 Dec 2018   -5850.0000  162810.9599  166920.0000
# 01 Jan 2019-31 Jan 2019  -74100.0000  -23083.1247  -49530.0000
# 01 Feb 2019-28 Feb 2019   -7000.0000    3500.0000    5600.0000
# 01 Mar 2019-31 Mar 2019       0.0000   49810.0000   49810.0000
# 01 Apr 2019-30 Apr 2019       0.0000    1000.0000     850.0000
# 01 May 2019-31 May 2019    -950.0000     475.0000     150.0000
# 01 Jun 2019-30 Jun 2019  -18000.0000    -480.0000  -10440.0000
# 01 Jul 2019-31 Jul 2019       0.0000   19000.0000   10830.0000
# 01 Aug 2019-31 Aug 2019       0.0000   22000.0000   14520.0000
# 01 Sep 2019-30 Sep 2019       0.0000    1600.0000    1420.0000
# 01 Oct 2019-31 Oct 2019 -146200.0000  -86853.7299 -110160.0000
# 01 Nov 2019-30 Nov 2019       0.0000    2250.0000    2040.0000
# 01 Dec 2019-31 Dec 2019    -100.0000    3500.0000    -100.0000
# 01 Jan 2020-31 Jan 2020  -57000.0000  -30974.0823  -35530.0000
# 01 Feb 2020-29 Feb 2020       0.0000   54000.0000   54000.0000
# 01 Mar 2020-31 Mar 2020  -86450.0000  124319.9997  124320.0000
# 01 Apr 2020-30 Apr 2020       0.0000    2975.0000    3370.0000
# 01 May 2020-31 May 2020  -11000.0000   12749.7289   11250.0000
# 01 Jun 2020-30 Jun 2020  -34800.0000   40015.6892   40680.0000
# 01 Jul 2020-31 Jul 2020  -55230.0000  -10428.2007  -55230.0000
# 01 Aug 2020-31 Aug 2020       0.0000  206149.9999  176510.0000
# 01 Sep 2020-30 Sep 2020  -39000.0000   59864.9999   59280.0000
# 01 Oct 2020-31 Oct 2020       0.0000   56000.0000   47400.0000
# 01 Nov 2020-30 Nov 2020  -10000.0000    -397.6192  -10000.0000
# 01 Dec 2020-31 Dec 2020  -52250.0000   -1959.3750  -50710.0000
# 01 Jan 2021-31 Jan 2021  -33150.0000   89419.9997   89420.0000
# 01 Feb 2021-28 Feb 2021  -91200.0000  -66149.9999  -89040.0000
# 01 Mar 2021-31 Mar 2021   -8250.0000     100.0000   -8250.0000
# 01 Apr 2021-30 Apr 2021 -150000.0000 -130000.0000 -135000.0000
# 01 May 2021-31 May 2021  -16200.0000    5400.0000    1080.0000
# 01 Jun 2021-30 Jun 2021 -102000.0000       0.0000 -102000.0000
# 01 Jul 2021-31 Jul 2021       0.0000   14300.0000   14300.0000
# 01 Aug 2021-31 Aug 2021  -64500.0000  -12181.0796  -20250.0000
# 01 Sep 2021-30 Sep 2021  -57600.0000   -7718.4271  -46560.0000
# 01 Oct 2021-31 Oct 2021  -25200.0000   64631.2500   51480.0000
# 01 Nov 2021-30 Nov 2021  -36100.0000   18050.0000   13490.0000
# 01 Dec 2021-31 Dec 2021       0.0000  117000.0001  117000.0000
# 01 Jan 2022-31 Jan 2022 -123500.0000  -97262.2428  -96460.0000
# 01 Feb 2022-28 Feb 2022 -138000.0000  -50000.0000  -50000.0000
# 01 Mar 2022-31 Mar 2022  -19800.0000   59400.0000   59400.0000
# 01 Apr 2022-30 Apr 2022 -119000.0000  -19270.0000 -117040.0000
# 01 May 2022-31 May 2022       0.0000  108526.7053   50160.0000
# 01 Jun 2022-30 Jun 2022  -64800.0000   67140.0000   47520.0000
# 01 Jul 2022-31 Jul 2022 -137200.0000   52666.6668   46480.0000
# 01 Aug 2022-31 Aug 2022  -89100.0000   35289.2670   48840.0000
# 01 Sep 2022-30 Sep 2022  -27750.0001   29099.9999   -7500.0001
# 01 Oct 2022-31 Oct 2022       0.0000  165000.0000  176000.0000
# 01 Nov 2022-30 Nov 2022 -137330.7840   59189.2161   59189.2160
# 01 Dec 2022-31 Dec 2022  -91000.0000    9377.5856  -11600.0000

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])

print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params))

# Adjust these parameter according to search space
n_trials = 10 #NGEN
npop = 100
early_stopping_gen = 10 # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters = [grid_params,lot_params]

results1 = walk_forward_analysis('jan 2018','jan 2021',1,parameters,optimization_function=deap_optimiser_g_n_std,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
results1
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# total_number_of_combinations:- 342.0
# Data gathered for training period:  01 Jan 2017 31 Dec 2017
# Data gathered for testing period:  01 Jan 2018 31 Jan 2018
# optimisation completed
# Optimal parameters are:  [0.007, 2000000]
# Max loss,R_PNL,profit are:  -164000.0 -132200.0 -132200.0
# Data gathered for training period:  01 Feb 2017 31 Jan 2018
# Data gathered for testing period:  01 Feb 2018 28 Feb 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 1800000]
# Max loss,R_PNL,profit are:  -46800.0 109200.0 61740.0
# Data gathered for training period:  01 Mar 2017 28 Feb 2018
# Data gathered for testing period:  01 Mar 2018 31 Mar 2018
# optimisation completed
# Optimal parameters are:  [0.007, 1900000]
# Max loss,R_PNL,profit are:  0 66500.0 79230.0
# Data gathered for training period:  01 Apr 2017 31 Mar 2018
# Data gathered for testing period:  01 Apr 2018 30 Apr 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000]
# Max loss,R_PNL,profit are:  0 30970.0 18810.0
# Data gathered for training period:  01 May 2017 30 Apr 2018
# Data gathered for testing period:  01 May 2018 31 May 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 1900000]
# Max loss,R_PNL,profit are:  -121737.5 -116037.5 -121737.5
# Data gathered for training period:  01 Jun 2017 31 May 2018
# Data gathered for testing period:  01 Jun 2018 30 Jun 2018
# optimisation completed
# Optimal parameters are:  [0.008, 1900000]
# Max loss,R_PNL,profit are:  -15200.0 76950.0 76950.0
# Data gathered for training period:  01 Jul 2017 30 Jun 2018
# Data gathered for testing period:  01 Jul 2018 31 Jul 2018
# optimisation completed
# Optimal parameters are:  [0.007, 2000000]
# Max loss,R_PNL,profit are:  0 56000.0 52600.0
# Data gathered for training period:  01 Aug 2017 31 Jul 2018
# Data gathered for testing period:  01 Aug 2018 31 Aug 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000]
# Max loss,R_PNL,profit are:  -125400.0 -6966.6667 -2280.0
# Data gathered for training period:  01 Sep 2017 31 Aug 2018
# Data gathered for testing period:  01 Sep 2018 30 Sep 2018
# optimisation completed
# Optimal parameters are:  [0.001, 100000]
# Max loss,R_PNL,profit are:  -7100.0 22460.0007 22520.0
# Data gathered for training period:  01 Oct 2017 30 Sep 2018
# Data gathered for testing period:  01 Oct 2018 31 Oct 2018
# optimisation completed
# Optimal parameters are:  [0.0075, 2000000]
# Max loss,R_PNL,profit are:  0 45000.0 8000.0
# Data gathered for training period:  01 Nov 2017 31 Oct 2018
# Data gathered for testing period:  01 Nov 2018 30 Nov 2018
# optimisation completed
# Optimal parameters are:  [0.0075, 2000000]
# Max loss,R_PNL,profit are:  -45000.0 50150.0 47800.0
# Data gathered for training period:  01 Dec 2017 30 Nov 2018
# Data gathered for testing period:  01 Dec 2018 31 Dec 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 1400000]
# Max loss,R_PNL,profit are:  0 69300.0 68040.0
# Data gathered for training period:  01 Jan 2018 31 Dec 2018
# Data gathered for testing period:  01 Jan 2019 31 Jan 2019
# optimisation completed
# Optimal parameters are:  [0.008, 1500000]
# Max loss,R_PNL,profit are:  -12000.0 42900.0 42900.0
# Data gathered for training period:  01 Feb 2018 31 Jan 2019
# Data gathered for testing period:  01 Feb 2019 28 Feb 2019
# optimisation completed
# Optimal parameters are:  [0.001, 500000]
# Max loss,R_PNL,profit are:  -66500.0 34523.6556 35000.0
# Data gathered for training period:  01 Mar 2018 28 Feb 2019
# Data gathered for testing period:  01 Mar 2019 31 Mar 2019
# optimisation completed
# Optimal parameters are:  [0.001, 800000]
# Max loss,R_PNL,profit are:  -103200.0 -45394.9476 -62400.0
# Data gathered for training period:  01 Apr 2018 31 Mar 2019
# Data gathered for testing period:  01 Apr 2019 30 Apr 2019
# optimisation completed
# Optimal parameters are:  [0.001, 600000]
# Max loss,R_PNL,profit are:  -600.0 39663.3801 48300.0
# Data gathered for training period:  01 May 2018 30 Apr 2019
# Data gathered for testing period:  01 May 2019 31 May 2019
# optimisation completed
# Optimal parameters are:  [0.001, 500000]
# Max loss,R_PNL,profit are:  -6000.0 41454.1667 34500.0
# Data gathered for training period:  01 Jun 2018 31 May 2019
# Data gathered for testing period:  01 Jun 2019 30 Jun 2019
# optimisation completed
# Optimal parameters are:  [0.001, 600000]
# Max loss,R_PNL,profit are:  -66000.0 -23302.7211 -24600.0
# Data gathered for training period:  01 Jul 2018 30 Jun 2019
# Data gathered for testing period:  01 Jul 2019 31 Jul 2019
# optimisation completed
# Optimal parameters are:  [0.001, 800000]
# Max loss,R_PNL,profit are:  -111200.0 -70924.5243 -63840.0
# Data gathered for training period:  01 Aug 2018 31 Jul 2019
# Data gathered for testing period:  01 Aug 2019 31 Aug 2019
# optimisation completed
# Optimal parameters are:  [0.001, 600000]
# Max loss,R_PNL,profit are:  -57000.0 56142.1672 36660.0
# Data gathered for training period:  01 Sep 2018 31 Aug 2019
# Data gathered for testing period:  01 Sep 2019 30 Sep 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1300000]
# Max loss,R_PNL,profit are:  -19500.0 85354.2861 85540.0
# Data gathered for training period:  01 Oct 2018 30 Sep 2019
# Data gathered for testing period:  01 Oct 2019 31 Oct 2019
# optimisation completed
# Optimal parameters are:  [0.0015, 1300000]
# Max loss,R_PNL,profit are:  -109200.0 -48750.0003 -64090.0
# Data gathered for training period:  01 Nov 2018 31 Oct 2019
# Data gathered for testing period:  01 Nov 2019 30 Nov 2019
# optimisation completed
# Optimal parameters are:  [0.001, 600000]
# Max loss,R_PNL,profit are:  -53400.0 -6655.386 -15240.0
# Data gathered for training period:  01 Dec 2018 30 Nov 2019
# Data gathered for testing period:  01 Dec 2019 31 Dec 2019
# optimisation completed
# Optimal parameters are:  [0.001, 600000]
# Max loss,R_PNL,profit are:  -51000.0 1058.8363 -31320.0
# Data gathered for training period:  01 Jan 2019 31 Dec 2019
# Data gathered for testing period:  01 Jan 2020 31 Jan 2020
# optimisation completed
# Optimal parameters are:  [0.001, 700000]
# Max loss,R_PNL,profit are:  -88900.0 -48754.4614 -63630.0
# Data gathered for training period:  01 Feb 2019 31 Jan 2020
# Data gathered for testing period:  01 Feb 2020 29 Feb 2020
# optimisation completed
# Optimal parameters are:  [0.0015, 900000]
# Max loss,R_PNL,profit are:  -179550.0 -79377.376 -87660.0
# Data gathered for training period:  01 Mar 2019 29 Feb 2020
# Data gathered for testing period:  01 Mar 2020 31 Mar 2020
# optimisation completed
# Optimal parameters are:  [0.001, 500000]
# Max loss,R_PNL,profit are:  -340000.0 -208373.4455 -203650.0
# Data gathered for training period:  01 Apr 2019 31 Mar 2020
# Data gathered for testing period:  01 Apr 2020 30 Apr 2020
# optimisation completed
# Optimal parameters are:  [0.001, 100000]
# Max loss,R_PNL,profit are:  -22300.0 16823.6231 22180.0
# Data gathered for training period:  01 May 2019 30 Apr 2020
# Data gathered for testing period:  01 May 2020 31 May 2020
# optimisation completed
# Optimal parameters are:  [0.001, 200000]
# Max loss,R_PNL,profit are:  -22000.0 25499.457 22500.0
# Data gathered for training period:  01 Jun 2019 31 May 2020
# Data gathered for testing period:  01 Jun 2020 30 Jun 2020
# optimisation completed
# Optimal parameters are:  [0.001, 200000]
# Max loss,R_PNL,profit are:  -66400.0 56433.0904 55240.0
# Data gathered for training period:  01 Jul 2019 30 Jun 2020
# Data gathered for testing period:  01 Jul 2020 31 Jul 2020
# optimisation completed
# Optimal parameters are:  [0.0085, 500000]
# Max loss,R_PNL,profit are:  -76600.0 4250.0 -76600.0
# Data gathered for training period:  01 Aug 2019 31 Jul 2020
# Data gathered for testing period:  01 Aug 2020 31 Aug 2020
# optimisation completed
# Optimal parameters are:  [0.0085, 1900000]
# Max loss,R_PNL,profit are:  0 68637.5 58140.0
# Data gathered for training period:  01 Sep 2019 31 Aug 2020
# Data gathered for testing period:  01 Sep 2020 30 Sep 2020
# optimisation completed
# Optimal parameters are:  [0.009, 2000000]
# Max loss,R_PNL,profit are:  0 35400.0 34800.0
# Data gathered for training period:  01 Oct 2019 30 Sep 2020
# Data gathered for testing period:  01 Oct 2020 31 Oct 2020
# optimisation completed
# Optimal parameters are:  [0.0045, 1700000]
# Max loss,R_PNL,profit are:  -15300.0 76500.0 75140.0
# Data gathered for training period:  01 Nov 2019 31 Oct 2020
# Data gathered for testing period:  01 Nov 2020 30 Nov 2020
# optimisation completed
# Optimal parameters are:  [0.0045, 900000]
# Max loss,R_PNL,profit are:  -82440.0 712.5 -82440.0
# Data gathered for training period:  01 Dec 2019 30 Nov 2020
# Data gathered for testing period:  01 Dec 2020 31 Dec 2020
# optimisation completed
# Optimal parameters are:  [0.01, 2000000]
# Max loss,R_PNL,profit are:  -40000.0 200.0 -39400.0
#                          max_loss        R_PNL    profit
# 01 Jan 2018-31 Jan 2018 -164000.0 -132200.0000 -132200.0
# 01 Feb 2018-28 Feb 2018  -46800.0  109200.0000   61740.0
# 01 Mar 2018-31 Mar 2018       0.0   66500.0000   79230.0
# 01 Apr 2018-30 Apr 2018       0.0   30970.0000   18810.0
# 01 May 2018-31 May 2018 -121737.5 -116037.5000 -121737.5
# 01 Jun 2018-30 Jun 2018  -15200.0   76950.0000   76950.0
# 01 Jul 2018-31 Jul 2018       0.0   56000.0000   52600.0
# 01 Aug 2018-31 Aug 2018 -125400.0   -6966.6667   -2280.0
# 01 Sep 2018-30 Sep 2018   -7100.0   22460.0007   22520.0
# 01 Oct 2018-31 Oct 2018       0.0   45000.0000    8000.0
# 01 Nov 2018-30 Nov 2018  -45000.0   50150.0000   47800.0
# 01 Dec 2018-31 Dec 2018       0.0   69300.0000   68040.0
# 01 Jan 2019-31 Jan 2019  -12000.0   42900.0000   42900.0
# 01 Feb 2019-28 Feb 2019  -66500.0   34523.6556   35000.0
# 01 Mar 2019-31 Mar 2019 -103200.0  -45394.9476  -62400.0
# 01 Apr 2019-30 Apr 2019    -600.0   39663.3801   48300.0
# 01 May 2019-31 May 2019   -6000.0   41454.1667   34500.0
# 01 Jun 2019-30 Jun 2019  -66000.0  -23302.7211  -24600.0
# 01 Jul 2019-31 Jul 2019 -111200.0  -70924.5243  -63840.0
# 01 Aug 2019-31 Aug 2019  -57000.0   56142.1672   36660.0
# 01 Sep 2019-30 Sep 2019  -19500.0   85354.2861   85540.0
# 01 Oct 2019-31 Oct 2019 -109200.0  -48750.0003  -64090.0
# 01 Nov 2019-30 Nov 2019  -53400.0   -6655.3860  -15240.0
# 01 Dec 2019-31 Dec 2019  -51000.0    1058.8363  -31320.0
# 01 Jan 2020-31 Jan 2020  -88900.0  -48754.4614  -63630.0
# 01 Feb 2020-29 Feb 2020 -179550.0  -79377.3760  -87660.0
# 01 Mar 2020-31 Mar 2020 -340000.0 -208373.4455 -203650.0
# 01 Apr 2020-30 Apr 2020  -22300.0   16823.6231   22180.0
# 01 May 2020-31 May 2020  -22000.0   25499.4570   22500.0
# 01 Jun 2020-30 Jun 2020  -66400.0   56433.0904   55240.0
# 01 Jul 2020-31 Jul 2020  -76600.0    4250.0000  -76600.0
# 01 Aug 2020-31 Aug 2020       0.0   68637.5000   58140.0
# 01 Sep 2020-30 Sep 2020       0.0   35400.0000   34800.0
# 01 Oct 2020-31 Oct 2020  -15300.0   76500.0000   75140.0
# 01 Nov 2020-30 Nov 2020  -82440.0     712.5000  -82440.0
# 01 Dec 2020-31 Dec 2020  -40000.0     200.0000  -39400.0

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])

print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params))

# Adjust these parameter according to search space
n_trials = 10 #NGEN
npop = 100
early_stopping_gen = 10 # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters = [grid_params,lot_params]

results1 = walk_forward_analysis('jan 2021','jan 2023',1,parameters,optimization_function=deap_optimiser_g_n_std,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
results1
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# total_number_of_combinations:- 342.0
# Data gathered for training period:  01 Jan 2020 31 Dec 2020
# Data gathered for testing period:  01 Jan 2021 31 Jan 2021
# optimisation completed
# Optimal parameters are:  [0.0085, 1800000]
# Max loss,R_PNL,profit are:  0 34425.0 42120.0
# Data gathered for training period:  01 Feb 2020 31 Jan 2021
# Data gathered for testing period:  01 Feb 2021 28 Feb 2021
# optimisation completed
# Optimal parameters are:  [0.0045, 2000000]
# Max loss,R_PNL,profit are:  -54000.0 72000.0 65600.0
# Data gathered for training period:  01 Mar 2020 28 Feb 2021
# Data gathered for testing period:  01 Mar 2021 31 Mar 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1800000]
# Max loss,R_PNL,profit are:  -72900.0 -30157.1707 -56340.0
# Data gathered for training period:  01 Apr 2020 31 Mar 2021
# Data gathered for testing period:  01 Apr 2021 30 Apr 2021
# optimisation completed
# Optimal parameters are:  [0.004, 1700000]
# Max loss,R_PNL,profit are:  -153000.0 -32087.5 -153000.0
# Data gathered for training period:  01 May 2020 30 Apr 2021
# Data gathered for testing period:  01 May 2021 31 May 2021
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000]
# Max loss,R_PNL,profit are:  0 32500.0 32200.0
# Data gathered for training period:  01 Jun 2020 31 May 2021
# Data gathered for testing period:  01 Jun 2021 30 Jun 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1800000]
# Max loss,R_PNL,profit are:  -153900.0 -74700.0002 -74700.0
# Data gathered for training period:  01 Jul 2020 30 Jun 2021
# Data gathered for testing period:  01 Jul 2021 31 Jul 2021
# optimisation completed
# Optimal parameters are:  [0.007, 2000000]
# Max loss,R_PNL,profit are:  -14000.0 42000.0 42000.0
# Data gathered for training period:  01 Aug 2020 31 Jul 2021
# Data gathered for testing period:  01 Aug 2021 31 Aug 2021
# optimisation completed
# Optimal parameters are:  [0.001, 200000]
# Max loss,R_PNL,profit are:  -25600.0 10338.928 14240.0
# Data gathered for training period:  01 Sep 2020 31 Aug 2021
# Data gathered for testing period:  01 Sep 2021 30 Sep 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 300000]
# Max loss,R_PNL,profit are:  -29250.0 4958.8518 -26100.0
# Data gathered for training period:  01 Oct 2020 30 Sep 2021
# Data gathered for testing period:  01 Oct 2021 31 Oct 2021
# optimisation completed
# Optimal parameters are:  [0.001, 100000]
# Max loss,R_PNL,profit are:  -900.0 11750.0003 11860.0
# Data gathered for training period:  01 Nov 2020 31 Oct 2021
# Data gathered for testing period:  01 Nov 2021 30 Nov 2021
# optimisation completed
# Optimal parameters are:  [0.001, 100000]
# Max loss,R_PNL,profit are:  -49900.0 -19981.6734 -14950.0
# Data gathered for training period:  01 Dec 2020 30 Nov 2021
# Data gathered for testing period:  01 Dec 2021 31 Dec 2021
# optimisation completed
# Optimal parameters are:  [0.0085, 2000000]
# Max loss,R_PNL,profit are:  0 3400.0 3400.0
# Data gathered for training period:  01 Jan 2021 31 Dec 2021
# Data gathered for testing period:  01 Jan 2022 31 Jan 2022
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\_.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=14'>15</a> optimizer_param = [n_trials, npop, early_stopping_gen]
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=16'>17</a> parameters = [grid_params,lot_params]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=18'>19</a> results1 = walk_forward_analysis('jan 2021','jan 2023',1,parameters,optimization_function=deap_optimiser_g_n_std,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=19'>20</a> results1
#
# File c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\GA_optimiser.py:62, in walk_forward_analysis(evaluation_start, evaluation_end, evaluation_day, parameters, optimization_function, optimizer_params, lookback_in_months, evaluation_period)
#      60 test_data = data_gather_from_files(dates[0],dates[1])['EURUSD.mid']
#      61 print('Data gathered for testing period: ',dates[0],dates[1])
# ---> 62 max_loss,R_PNL,profit,optimal_params = optimization_function(train_data,test_data,parameters,optimizer_params)
#      63 print('Optimal parameters are: ',optimal_params)
#      64 print('Max loss,R_PNL,profit are: ',max_loss, R_PNL,profit)
#
# c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\_.ipynb Cell 8 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=79'>80</a>         toolbox.mutate(mutant)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=80'>81</a>         del mutant.fitness.values
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=82'>83</a> fitnesses = list(map(toolbox.evaluate, offspring))
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=83'>84</a> for ind, fit in zip(offspring, fitnesses):
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=84'>85</a>     ind.fitness.values = fit
#
# c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\_.ipynb Cell 8 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=34'>35</a> def objective(individual):
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=35'>36</a>     G, n = individual[0]*grid_params[2], individual[1]*position_params[2]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=36'>37</a>     max_loss, R_PNL, profit, std = run_strategy_optimised(train_data, G, n)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=38'>39</a>     constraints = [
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=39'>40</a>         max_loss < -500e3
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=40'>41</a>     ]
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X42sZmlsZQ%3D%3D?line=42'>43</a>     if any(constraints):
#
# File c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\bp.py:813, in run_strategy_optimised(tick_data, grid_sizing, lot_sizing, ladder_function, multiplier, indicator_type, indicator_scale, lookback)
#     776 def run_strategy_optimised(tick_data, grid_sizing, lot_sizing,
#     777                            ladder_function=ladderize_absolute_optimised, multiplier=1,
#     778                            indicator_type='d', indicator_scale=5, lookback=200):
#     779     """
#     780     Execute a quant trading strategy using provided tick data and parameters.
#     781
#    (...)
#     810         Total PNL at the end of the strategy.
#     811     """
# --> 813     grid_jumps,binomial_data = convert_to_grid_binomial_data(tick_data,grid_sizing,ladder_function)
#     814     indicator_data = indicator_prep(grid_jumps,grid_sizing,lookback=lookback,Type=indicator_type,indicator_scale=indicator_scale)
#     816     T = len(binomial_data)
#
# File c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\bp.py:416, in convert_to_grid_binomial_data(tick_data, grid_size, ladderized_function)
#     392 """
#     393 Convert tick data to a binomial grid representation using a ladderized function.
#     394
#    (...)
#     413 The binomial data would be [0, 1, 1, 1]
#     414 """
#     415 ladderized_data = ladderized_function(tick_data,grid_size)
# --> 416 jumps = filter_jumps(ladderized_data)
#     417 binomial_data = jumps.diff()
#     418 binomial_data[1:] = np.where(binomial_data[1:] > 0,1,-1) # 1 for up and -1 for down
#
# File c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\bp.py:327, in filter_jumps(ladderized_data)
#     320 """
#     321 Filters ladderized data to keep only the changes in price.
#     322
#     323 :param ladderized_data: A pandas Series of ladderized data.
#     324 :return: A pandas Series containing only the data points where there's a change.
#     325 """
#     326 # Calculate the difference between consecutive ladderized data points
# --> 327 diff = ladderized_data.diff()
#     329 # Filter where the difference is non-zero and include the first data point
#     330 jumps = ladderized_data[diff != 0.0]
#
# File c:\Users\Jenny\anaconda3\Lib\site-packages\pandas\core\series.py:2903, in Series.diff(self, periods)
#    2818 @doc(
#    2819     klass="Series",
#    2820     extra_params="",
#    (...)
#    2866 )
#    2867 def diff(self, periods: int = 1) -> Series:
#    2868     """
#    2869     First discrete difference of element.
#    2870
#    (...)
#    2901     {examples}
#    2902     """
# -> 2903     result = algorithms.diff(self._values, periods)
#    2904     return self._constructor(result, index=self.index).__finalize__(
#    2905         self, method="diff"
#    2906     )
#
# File c:\Users\Jenny\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1767, in diff(arr, n, axis)
#    1762 out_arr[tuple(na_indexer)] = na
#    1764 if arr.dtype.name in _diff_special:
#    1765     # TODO: can diff_2d dtype specialization troubles be fixed by defining
#    1766     #  out_arr inside diff_2d?
# -> 1767     algos.diff_2d(arr, out_arr, n, axis, datetimelike=is_timedelta)
#    1768 else:
#    1769     # To keep mypy happy, _res_indexer is a list while res_indexer is
#    1770     #  a tuple, ditto for lag_indexer.
#    1771     _res_indexer = [slice(None)] * 2
#
# KeyboardInterrupt:

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])

print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params))

# Adjust these parameter according to search space
n_trials = 10 #NGEN
npop = 100
early_stopping_gen = 10 # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters = [grid_params,lot_params]

results1 = walk_forward_analysis('jan 2021','jan 2023',1,parameters,optimization_function=deap_optimiser_g_n_std,optimizer_params=optimizer_param,lookback_in_months=3,evaluation_period=1)
results1
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# total_number_of_combinations:- 342.0
# Data gathered for training period:  01 Oct 2020 31 Dec 2020
# Data gathered for testing period:  01 Jan 2021 31 Jan 2021
# optimisation completed
# Optimal parameters are:  [0.0015, 1700000]
# Max loss,R_PNL,profit are:  -33150.0 89419.9997 89420.0
# Data gathered for training period:  01 Nov 2020 31 Jan 2021
# Data gathered for testing period:  01 Feb 2021 28 Feb 2021
# optimisation completed
# Optimal parameters are:  [0.001, 1600000]
# Max loss,R_PNL,profit are:  -137600.0 -112174.4726 -135200.0
# Data gathered for training period:  01 Dec 2020 28 Feb 2021
# Data gathered for testing period:  01 Mar 2021 31 Mar 2021
# optimisation completed
# Optimal parameters are:  [0.008, 100000]
# Max loss,R_PNL,profit are:  -8250.0 100.0 -8250.0
# Data gathered for training period:  01 Jan 2021 31 Mar 2021
# Data gathered for testing period:  01 Apr 2021 30 Apr 2021
# optimisation completed
# Optimal parameters are:  [0.005, 2000000]
# Max loss,R_PNL,profit are:  -150000.0 -130000.0 -135000.0
# Data gathered for training period:  01 Feb 2021 30 Apr 2021
# Data gathered for testing period:  01 May 2021 31 May 2021
# optimisation completed
# Optimal parameters are:  [0.009, 1800000]
# Max loss,R_PNL,profit are:  -32400.0 10800.0 2160.0
# Data gathered for training period:  01 Mar 2021 31 May 2021
# Data gathered for testing period:  01 Jun 2021 30 Jun 2021
# optimisation completed
# Optimal parameters are:  [0.01, 1700000]
# Max loss,R_PNL,profit are:  -102000.0 0 -102000.0
# Data gathered for training period:  01 Apr 2021 30 Jun 2021
# Data gathered for testing period:  01 Jul 2021 31 Jul 2021
# optimisation completed
# Optimal parameters are:  [0.01, 200000]
# Max loss,R_PNL,profit are:  0 2600.0 2600.0
# Data gathered for training period:  01 May 2021 31 Jul 2021
# Data gathered for testing period:  01 Aug 2021 31 Aug 2021
# optimisation completed
# Optimal parameters are:  [0.009, 300000]
# Max loss,R_PNL,profit are:  0 5400.0 5400.0
# Data gathered for training period:  01 Jun 2021 31 Aug 2021
# Data gathered for testing period:  01 Sep 2021 30 Sep 2021
# optimisation completed
# Optimal parameters are:  [0.001, 1400000]
# Max loss,R_PNL,profit are:  -58800.0 -13745.5998 -47600.0
# Data gathered for training period:  01 Jul 2021 30 Sep 2021
# Data gathered for testing period:  01 Oct 2021 31 Oct 2021
# optimisation completed
# Optimal parameters are:  [0.001, 1800000]
# Max loss,R_PNL,profit are:  -25200.0 64631.25 51480.0
# Data gathered for training period:  01 Aug 2021 31 Oct 2021
# Data gathered for testing period:  01 Nov 2021 30 Nov 2021
# optimisation completed
# Optimal parameters are:  [0.0095, 1300000]
# Max loss,R_PNL,profit are:  -24700.0 12350.0 9230.0
# Data gathered for training period:  01 Sep 2021 30 Nov 2021
# Data gathered for testing period:  01 Dec 2021 31 Dec 2021
# optimisation completed
# Optimal parameters are:  [0.0085, 200000]
# Max loss,R_PNL,profit are:  0 340.0 340.0
# Data gathered for training period:  01 Oct 2021 31 Dec 2021
# Data gathered for testing period:  01 Jan 2022 31 Jan 2022
# optimisation completed
# Optimal parameters are:  [0.001, 1300000]
# Max loss,R_PNL,profit are:  -123500.0 -97262.2428 -96460.0
# Data gathered for training period:  01 Nov 2021 31 Jan 2022
# Data gathered for testing period:  01 Feb 2022 28 Feb 2022
# optimisation completed
# Optimal parameters are:  [0.001, 1300000]
# Max loss,R_PNL,profit are:  -126100.0 -44362.4998 -42900.0
# Data gathered for training period:  01 Dec 2021 28 Feb 2022
# Data gathered for testing period:  01 Mar 2022 31 Mar 2022
# optimisation completed
# Optimal parameters are:  [0.009, 1100000]
# Max loss,R_PNL,profit are:  -19800.0 59400.0 59400.0
# Data gathered for training period:  01 Jan 2022 31 Mar 2022
# Data gathered for testing period:  01 Apr 2022 30 Apr 2022
# optimisation completed
# Optimal parameters are:  [0.0085, 800000]
# Max loss,R_PNL,profit are:  -136000.0 -22022.8571 -133760.0
# Data gathered for training period:  01 Feb 2022 30 Apr 2022
# Data gathered for testing period:  01 May 2022 31 May 2022
# optimisation completed
# Optimal parameters are:  [0.007, 1900000]
# Max loss,R_PNL,profit are:  0 74480.0 18620.0
# Data gathered for training period:  01 Mar 2022 31 May 2022
# Data gathered for testing period:  01 Jun 2022 30 Jun 2022
# optimisation completed
# Optimal parameters are:  [0.006, 1800000]
# Max loss,R_PNL,profit are:  -64800.0 67140.0 47520.0
# Data gathered for training period:  01 Apr 2022 30 Jun 2022
# Data gathered for testing period:  01 Jul 2022 31 Jul 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1600000]
# Max loss,R_PNL,profit are:  -137200.0 52666.6668 46480.0
# Data gathered for training period:  01 May 2022 31 Jul 2022
# Data gathered for testing period:  01 Aug 2022 31 Aug 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1200000]
# Max loss,R_PNL,profit are:  -50400.0 67937.143 79800.0
# Data gathered for training period:  01 Jun 2022 31 Aug 2022
# Data gathered for testing period:  01 Sep 2022 30 Sep 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1500000]
# Max loss,R_PNL,profit are:  -27750.0001 29099.9999 -7500.0001
# Data gathered for training period:  01 Jul 2022 30 Sep 2022
# Data gathered for testing period:  01 Oct 2022 31 Oct 2022
# optimisation completed
# Optimal parameters are:  [0.004, 1500000]
# Max loss,R_PNL,profit are:  -48000.0 104527.7778 104250.0
# Data gathered for training period:  01 Aug 2022 31 Oct 2022
# Data gathered for testing period:  01 Nov 2022 30 Nov 2022
# optimisation completed
# Optimal parameters are:  [0.0035, 1700000]
# Max loss,R_PNL,profit are:  -137330.784 59189.2161 59189.216
# Data gathered for training period:  01 Sep 2022 30 Nov 2022
# Data gathered for testing period:  01 Dec 2022 31 Dec 2022
# optimisation completed
# Optimal parameters are:  [0.001, 100000]
# Max loss,R_PNL,profit are:  -19200.0 16634.1499 5410.0
#                             max_loss        R_PNL       profit
# 01 Jan 2021-31 Jan 2021  -33150.0000   89419.9997   89420.0000
# 01 Feb 2021-28 Feb 2021 -137600.0000 -112174.4726 -135200.0000
# 01 Mar 2021-31 Mar 2021   -8250.0000     100.0000   -8250.0000
# 01 Apr 2021-30 Apr 2021 -150000.0000 -130000.0000 -135000.0000
# 01 May 2021-31 May 2021  -32400.0000   10800.0000    2160.0000
# 01 Jun 2021-30 Jun 2021 -102000.0000       0.0000 -102000.0000
# 01 Jul 2021-31 Jul 2021       0.0000    2600.0000    2600.0000
# 01 Aug 2021-31 Aug 2021       0.0000    5400.0000    5400.0000
# 01 Sep 2021-30 Sep 2021  -58800.0000  -13745.5998  -47600.0000
# 01 Oct 2021-31 Oct 2021  -25200.0000   64631.2500   51480.0000
# 01 Nov 2021-30 Nov 2021  -24700.0000   12350.0000    9230.0000
# 01 Dec 2021-31 Dec 2021       0.0000     340.0000     340.0000
# 01 Jan 2022-31 Jan 2022 -123500.0000  -97262.2428  -96460.0000
# 01 Feb 2022-28 Feb 2022 -126100.0000  -44362.4998  -42900.0000
# 01 Mar 2022-31 Mar 2022  -19800.0000   59400.0000   59400.0000
# 01 Apr 2022-30 Apr 2022 -136000.0000  -22022.8571 -133760.0000
# 01 May 2022-31 May 2022       0.0000   74480.0000   18620.0000
# 01 Jun 2022-30 Jun 2022  -64800.0000   67140.0000   47520.0000
# 01 Jul 2022-31 Jul 2022 -137200.0000   52666.6668   46480.0000
# 01 Aug 2022-31 Aug 2022  -50400.0000   67937.1430   79800.0000
# 01 Sep 2022-30 Sep 2022  -27750.0001   29099.9999   -7500.0001
# 01 Oct 2022-31 Oct 2022  -48000.0000  104527.7778  104250.0000
# 01 Nov 2022-30 Nov 2022 -137330.7840   59189.2161   59189.2160
# 01 Dec 2022-31 Dec 2022  -19200.0000   16634.1499    5410.0000

# %% [markdown]
# # Group 3 optimization without std

# %%
def deap_optimiser_indicator(train_data, test_data, parameters, optimization_params):
    ngen = optimization_params[0]  # number of generations
    npop = optimization_params[1]  # number of population

    error_check(parameters,5)
    
    grid_params = parameters[0]
    position_params = parameters[1]
    indicator_type_params = parameters[2]
    lookback_params = parameters[3]
    scaling_factor_params = parameters[4]

    creator.create("FitnessMax", base.Fitness, weights=(1.0,)) #maximizing
    creator.create("Individual", list, fitness=creator.FitnessMax)

    toolbox = base.Toolbox()

    # Define the genes for our individual
    toolbox.register("G_gene", random.randint, grid_params[0]//grid_params[2], grid_params[1]//grid_params[2])
    toolbox.register("n_gene", random.randint, position_params[0]//position_params[2], position_params[1]//position_params[2])
    toolbox.register("indicator_gene", random.choice, indicator_type_params)
    toolbox.register("lookback_gene", random.choice, lookback_params)
    toolbox.register("scaling_gene", random.randint, scaling_factor_params[0]//scaling_factor_params[2], scaling_factor_params[1]//scaling_factor_params[2])

    CXPB, MUTPB = 0.5, 0.2

    def custom_mutate(individual): 
        if random.random() < MUTPB:
            individual[0] = random.randint(grid_params[0]//grid_params[2], grid_params[1]//grid_params[2])
        if random.random() < MUTPB:
            individual[1] = random.randint(position_params[0]//position_params[2], position_params[1]//position_params[2])
        if random.random() < MUTPB:
           individual[2] = random.choice(indicator_type_params)
        if random.random() < MUTPB:
            individual[3] = random.choice(lookback_params)
        if random.random() < MUTPB:
            individual[4] = random.randint(scaling_factor_params[0]//scaling_factor_params[2], scaling_factor_params[1]//scaling_factor_params[2])

        return individual,

    toolbox.register("mutate", custom_mutate)

    # Create an individual with the genes
    toolbox.register("individual", tools.initCycle, creator.Individual, (toolbox.G_gene, toolbox.n_gene, toolbox.indicator_gene, toolbox.lookback_gene, toolbox.scaling_gene), n=1)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    def objective(individual):
        G, n, indicator_type, lookback, scaling_factor = individual[0]*grid_params[2], individual[1]*position_params[2], individual[2], individual[3], individual[4]*scaling_factor_params[2]

        max_loss, R_PNL, profit, _ = run_strategy_optimised(train_data, G, n, indicator_type = indicator_type, lookback = lookback, indicator_scale = scaling_factor)
    
        constraints = [
            max_loss < -500e3
        ]

        if any(constraints):
            return float('-inf'),  # Return large negative value when constraints are not satisfied
        return profit,

    toolbox.register("mate", tools.cxTwoPoint)
    toolbox.register("select", tools.selTournament, tournsize=3)   
    toolbox.register("evaluate", objective)

    population = toolbox.population(n=npop)

    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit

    #initiate early stopping
    stagnant_generations = 0  # Counter for generations without improvement
    MAX_STAGNANT_GEN = optimization_params[2]  # Early stopping criterion: stop if no improvement over x generations
    best_fitness_so_far = float('-inf')  # since we're maximizing
    ##
    for gen in range(ngen):
        offspring = toolbox.select(population, len(population))
        offspring = list(map(toolbox.clone, offspring))
        
        # Crossover
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CXPB:
                toolbox.mate(child1, child2)
                del child1.fitness.values
                del child2.fitness.values
        
        # Mutation
        for mutant in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        fitnesses = list(map(toolbox.evaluate, offspring))
        for ind, fit in zip(offspring, fitnesses):
            ind.fitness.values = fit

        #early stopping
        current_best_fitness = max(ind.fitness.values[0] for ind in population)

        if current_best_fitness > best_fitness_so_far:
            best_fitness_so_far = current_best_fitness
            stagnant_generations = 0  # Reset counter
        else:
            stagnant_generations += 1

        if stagnant_generations >= MAX_STAGNANT_GEN:
            print(f"Early stopping on generation {gen} due to no improvement.")
            break
        ##
        population[:] = offspring

    best_ind = tools.selBest(population, 1)[0]
    optimal_g = np.round(best_ind[0]*grid_params[2],5)
    optimal_n = best_ind[1]*position_params[2]
    optimal_type = best_ind[2]
    optimal_l = best_ind[3]
    optimal_scaling = np.round(best_ind[4] *scaling_factor_params[2],5)

    print("optimisation completed")
    max_loss, R_PNL,profit,std  = run_strategy_optimised(test_data, optimal_g,optimal_n,indicator_type = optimal_type,lookback = optimal_l,indicator_scale=optimal_scaling)
    return max_loss, R_PNL,profit,[optimal_g,optimal_n,optimal_type,optimal_l,optimal_scaling]

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]
I_type = ['v','a']
lookback_params = [9,20,30,50,100,150,200]
scaling_factor_params = [1,3,0.1]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])
n_I_type_params = len(I_type)
n_lookback_params = len(lookback_params)
n_scaling_factor_params = ((scaling_factor_params[1]-scaling_factor_params[0])/scaling_factor_params[2])
print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('number of I_type params:-',(n_I_type_params))
print('number of lookback params:-',(n_lookback_params))
print('number of scaling_factor params:-',(n_scaling_factor_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params*n_I_type_params*n_lookback_params*n_scaling_factor_params))


# Adjust these parameter according to search space
n_trials = 50 #NGEN
npop = 100
early_stopping_gen = n_trials # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters2 = [grid_params,lot_params,I_type,lookback_params,scaling_factor_params]

results2 = walk_forward_analysis('jan 2018','jan 2023',1,parameters2,optimization_function=deap_optimiser_indicator,optimizer_params=optimizer_param,lookback_in_months=3,evaluation_period=1)
results2

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]
I_type = ['v','a']
lookback_params = [9,20,30,50,100,150,200]
scaling_factor_params = [1,3,0.1]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])
n_I_type_params = len(I_type)
n_lookback_params = len(lookback_params)
n_scaling_factor_params = ((scaling_factor_params[1]-scaling_factor_params[0])/scaling_factor_params[2])
print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('number of I_type params:-',(n_I_type_params))
print('number of lookback params:-',(n_lookback_params))
print('number of scaling_factor params:-',(n_scaling_factor_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params*n_I_type_params*n_lookback_params*n_scaling_factor_params))


# Adjust these parameter according to search space
n_trials = 50 #NGEN
npop = 100
early_stopping_gen = n_trials # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters2 = [grid_params,lot_params,I_type,lookback_params,scaling_factor_params]

results2 = walk_forward_analysis('jan 2018','jan 2023',1,parameters2,optimization_function=deap_optimiser_indicator,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
results2
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# number of I_type params:- 2
# number of lookback params:- 7
# number of scaling_factor params:- 20.0
# total_number_of_combinations:- 95760.0
# Data gathered for training period:  01 Jan 2017 31 Dec 2017
# Data gathered for testing period:  01 Jan 2018 31 Jan 2018
# optimisation completed
# Optimal parameters are:  [0.007, 2000000, 'v', 20, 2.2]
# Max loss,R_PNL,profit are:  -211292.6829 -179657.3888 -182852.6829
# Data gathered for training period:  01 Feb 2017 31 Jan 2018
# Data gathered for testing period:  01 Feb 2018 28 Feb 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 1400000, 'v', 9, 2.8]
# Max loss,R_PNL,profit are:  -63700.0 35685.0 9128.0
# Data gathered for training period:  01 Mar 2017 28 Feb 2018
# Data gathered for testing period:  01 Mar 2018 31 Mar 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 1700000, 'v', 9, 2.7]
# Max loss,R_PNL,profit are:  -20995.0 77452.0 77452.0
# Data gathered for training period:  01 Apr 2017 31 Mar 2018
# Data gathered for testing period:  01 Apr 2018 30 Apr 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 2000000, 'v', 9, 2.5]
# Max loss,R_PNL,profit are:  -3900.0 23798.7097 16560.0
# Data gathered for training period:  01 May 2017 30 Apr 2018
# Data gathered for testing period:  01 May 2018 31 May 2018
# optimisation completed
# Optimal parameters are:  [0.0065, 1700000, 'v', 9, 2.6]
# Max loss,R_PNL,profit are:  0 71910.0 71910.0
# Data gathered for training period:  01 Jun 2017 31 May 2018
# Data gathered for testing period:  01 Jun 2018 30 Jun 2018
# optimisation completed
# Optimal parameters are:  [0.0035, 1800000, 'v', 50, 2.9]
# Max loss,R_PNL,profit are:  -65520.0 24735.4838 5490.0
# Data gathered for training period:  01 Jul 2017 30 Jun 2018
# Data gathered for testing period:  01 Jul 2018 31 Jul 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 30, 1.0]
# Max loss,R_PNL,profit are:  -11000.0 95860.0 95860.0
# Data gathered for training period:  01 Aug 2017 31 Jul 2018
# Data gathered for testing period:  01 Aug 2018 31 Aug 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 1900000, 'a', 200, 2.7]
# Max loss,R_PNL,profit are:  -128535.0 -36422.2772 -34314.0
# Data gathered for training period:  01 Sep 2017 31 Aug 2018
# Data gathered for testing period:  01 Sep 2018 30 Sep 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 20, 1.7]
# Max loss,R_PNL,profit are:  -8800.0 72639.9999 72640.0
# Data gathered for training period:  01 Oct 2017 30 Sep 2018
# Data gathered for testing period:  01 Oct 2018 31 Oct 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 20, 1.6]
# Max loss,R_PNL,profit are:  -33000.0 49185.7143 -22500.0
# Data gathered for training period:  01 Nov 2017 31 Oct 2018
# Data gathered for testing period:  01 Nov 2018 30 Nov 2018
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 20, 1.9]
# Max loss,R_PNL,profit are:  -37400.0 74800.0 65640.0
# Data gathered for training period:  01 Dec 2017 30 Nov 2018
# Data gathered for testing period:  01 Dec 2018 31 Dec 2018
# optimisation completed
# Optimal parameters are:  [0.0045, 1700000, 'v', 30, 1.3]
# Max loss,R_PNL,profit are:  0 90270.0001 90117.0
# Data gathered for training period:  01 Jan 2018 31 Dec 2018
# Data gathered for testing period:  01 Jan 2019 31 Jan 2019
# optimisation completed
# Optimal parameters are:  [0.0045, 1900000, 'v', 100, 1.0]
# Max loss,R_PNL,profit are:  -1710.0 81225.0 75943.0
# Data gathered for training period:  01 Feb 2018 31 Jan 2019
# Data gathered for testing period:  01 Feb 2019 28 Feb 2019
# optimisation completed
# Optimal parameters are:  [0.0055, 2000000, 'v', 100, 2.5]
# Max loss,R_PNL,profit are:  -66000.0 1100.0 4100.0
# Data gathered for training period:  01 Mar 2018 28 Feb 2019
# Data gathered for testing period:  01 Mar 2019 31 Mar 2019
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\_.ipynb Cell 15 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=23'>24</a> optimizer_param = [n_trials, npop, early_stopping_gen]
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=25'>26</a> parameters2 = [grid_params,lot_params,I_type,lookback_params,scaling_factor_params]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=27'>28</a> results2 = walk_forward_analysis('jan 2018','jan 2023',1,parameters2,optimization_function=deap_optimiser_indicator,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=28'>29</a> results2
#
# File c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\GA_optimiser.py:62, in walk_forward_analysis(evaluation_start, evaluation_end, evaluation_day, parameters, optimization_function, optimizer_params, lookback_in_months, evaluation_period)
#      60 test_data = data_gather_from_files(dates[0],dates[1])['EURUSD.mid']
#      61 print('Data gathered for testing period: ',dates[0],dates[1])
# ---> 62 max_loss,R_PNL,profit,optimal_params = optimization_function(train_data,test_data,parameters,optimizer_params)
#      63 print('Optimal parameters are: ',optimal_params)
#      64 print('Max loss,R_PNL,profit are: ',max_loss, R_PNL,profit)
#
# c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\_.ipynb Cell 15 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=89'>90</a>         toolbox.mutate(mutant)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=90'>91</a>         del mutant.fitness.values
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=92'>93</a> fitnesses = list(map(toolbox.evaluate, offspring))
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=93'>94</a> for ind, fit in zip(offspring, fitnesses):
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=94'>95</a>     ind.fitness.values = fit
#
# c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\_.ipynb Cell 15 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=46'>47</a> def objective(individual):
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=47'>48</a>     G, n, indicator_type, lookback, scaling_factor = individual[0]*grid_params[2], individual[1]*position_params[2], individual[2], individual[3], individual[4]*scaling_factor_params[2]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=49'>50</a>     max_loss, R_PNL, profit, _ = run_strategy_optimised(train_data, G, n, indicator_type = indicator_type, lookback = lookback, indicator_scale = scaling_factor)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=51'>52</a>     constraints = [
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=52'>53</a>         max_loss < -500e3
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=53'>54</a>     ]
#      <a href='vscode-notebook-cell:/c%3A/Users/Jenny/Documents/UIUC_workspace/Practicum/bp-Trading/_.ipynb#X15sZmlsZQ%3D%3D?line=55'>56</a>     if any(constraints):
#
# File c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\bp.py:813, in run_strategy_optimised(tick_data, grid_sizing, lot_sizing, ladder_function, multiplier, indicator_type, indicator_scale, lookback)
#     776 def run_strategy_optimised(tick_data, grid_sizing, lot_sizing,
#     777                            ladder_function=ladderize_absolute_optimised, multiplier=1,
#     778                            indicator_type='d', indicator_scale=5, lookback=200):
#     779     """
#     780     Execute a quant trading strategy using provided tick data and parameters.
#     781
#    (...)
#     810         Total PNL at the end of the strategy.
#     811     """
# --> 813     grid_jumps,binomial_data = convert_to_grid_binomial_data(tick_data,grid_sizing,ladder_function)
#     814     indicator_data = indicator_prep(grid_jumps,grid_sizing,lookback=lookback,Type=indicator_type,indicator_scale=indicator_scale)
#     816     T = len(binomial_data)
#
# File c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\bp.py:415, in convert_to_grid_binomial_data(tick_data, grid_size, ladderized_function)
#     391 def convert_to_grid_binomial_data(tick_data,grid_size,ladderized_function):
#     392     """
#     393     Convert tick data to a binomial grid representation using a ladderized function.
#     394
#    (...)
#     413     The binomial data would be [0, 1, 1, 1]
#     414     """
# --> 415     ladderized_data = ladderized_function(tick_data,grid_size)
#     416     jumps = filter_jumps(ladderized_data)
#     417     binomial_data = jumps.diff()
#
# File c:\Users\Jenny\Documents\UIUC_workspace\Practicum\bp-Trading\bp.py:306, in ladderize_absolute_optimised(tick_data, grid_size)
#     303 # Round the opening price for grid calculations
#     304 rounded_open = (tick_data.iloc[0] / grid_size).round() * grid_size
# --> 306 tick_data_np = tick_data.values.astype(np.float64)
#     308 ladderize_absolute_loop(n, tick_data_np, ladderized_data, grid_size, rounded_open)
#     310 # Overwrite the last tick to the exact closing price
#
# KeyboardInterrupt:

# %% [markdown]
# ## Group 3 Optimization with std

# %%
def deap_optimiser_indicator_std(train_data, test_data, parameters, optimization_params):
    ngen = optimization_params[0]  # number of generations
    npop = optimization_params[1]  # number of population

    error_check(parameters,5)
    
    grid_params = parameters[0]
    position_params = parameters[1]
    indicator_type_params = parameters[2]
    lookback_params = parameters[3]
    scaling_factor_params = parameters[4]

    creator.create("FitnessMax", base.Fitness, weights=(1.0,)) #maximizing
    creator.create("Individual", list, fitness=creator.FitnessMax)

    toolbox = base.Toolbox()

    # Define the genes for our individual
    toolbox.register("G_gene", random.randint, grid_params[0]//grid_params[2], grid_params[1]//grid_params[2])
    toolbox.register("n_gene", random.randint, position_params[0]//position_params[2], position_params[1]//position_params[2])
    toolbox.register("indicator_gene", random.choice, indicator_type_params)
    toolbox.register("lookback_gene", random.choice, lookback_params)
    toolbox.register("scaling_gene", random.randint, scaling_factor_params[0]//scaling_factor_params[2], scaling_factor_params[1]//scaling_factor_params[2])

    CXPB, MUTPB = 0.5, 0.2

    def custom_mutate(individual): 
        if random.random() < MUTPB:
            individual[0] = random.randint(grid_params[0]//grid_params[2], grid_params[1]//grid_params[2])
        if random.random() < MUTPB:
            individual[1] = random.randint(position_params[0]//position_params[2], position_params[1]//position_params[2])
        if random.random() < MUTPB:
           individual[2] = random.choice(indicator_type_params)
        if random.random() < MUTPB:
            individual[3] = random.choice(lookback_params)
        if random.random() < MUTPB:
            individual[4] = random.randint(scaling_factor_params[0]//scaling_factor_params[2], scaling_factor_params[1]//scaling_factor_params[2])

        return individual,

    toolbox.register("mutate", custom_mutate)

    # Create an individual with the genes
    toolbox.register("individual", tools.initCycle, creator.Individual, (toolbox.G_gene, toolbox.n_gene, toolbox.indicator_gene, toolbox.lookback_gene, toolbox.scaling_gene), n=1)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    def objective(individual):
        G, n, indicator_type, lookback, scaling_factor = individual[0]*grid_params[2], individual[1]*position_params[2], individual[2], individual[3], individual[4]*scaling_factor_params[2]

        max_loss, R_PNL, profit, std = run_strategy_optimised(train_data, G, n, indicator_type = indicator_type, lookback = lookback, indicator_scale = scaling_factor)
    
        constraints = [
            max_loss < -500e3
        ]

        if any(constraints):
            return float('-inf'),  # Return large negative value when constraints are not satisfied
        return profit/std,

    toolbox.register("mate", tools.cxTwoPoint)
    toolbox.register("select", tools.selTournament, tournsize=3)   
    toolbox.register("evaluate", objective)

    population = toolbox.population(n=npop)

    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit

    #initiate early stopping
    stagnant_generations = 0  # Counter for generations without improvement
    MAX_STAGNANT_GEN = optimization_params[2]  # Early stopping criterion: stop if no improvement over x generations
    best_fitness_so_far = float('-inf')  # since we're maximizing
    ##
    for gen in range(ngen):
        offspring = toolbox.select(population, len(population))
        offspring = list(map(toolbox.clone, offspring))
        
        # Crossover
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CXPB:
                toolbox.mate(child1, child2)
                del child1.fitness.values
                del child2.fitness.values
        
        # Mutation
        for mutant in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        fitnesses = list(map(toolbox.evaluate, offspring))
        for ind, fit in zip(offspring, fitnesses):
            ind.fitness.values = fit

        #early stopping
        current_best_fitness = max(ind.fitness.values[0] for ind in population)

        if current_best_fitness > best_fitness_so_far:
            best_fitness_so_far = current_best_fitness
            stagnant_generations = 0  # Reset counter
        else:
            stagnant_generations += 1

        if stagnant_generations >= MAX_STAGNANT_GEN:
            print(f"Early stopping on generation {gen} due to no improvement.")
            break
        ##
        population[:] = offspring

    best_ind = tools.selBest(population, 1)[0]
    optimal_g = np.round(best_ind[0]*grid_params[2],5)
    optimal_n = best_ind[1]*position_params[2]
    optimal_type = best_ind[2]
    optimal_l = best_ind[3]
    optimal_scaling = np.round(best_ind[4] *scaling_factor_params[2],5)

    print("optimisation completed")
    max_loss, R_PNL,profit,std  = run_strategy_optimised(test_data, optimal_g,optimal_n,indicator_type = optimal_type,lookback = optimal_l,indicator_scale=optimal_scaling)
    return max_loss, R_PNL,profit,[optimal_g,optimal_n,optimal_type,optimal_l,optimal_scaling]

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]
I_type = ['v','a']
lookback_params = [9,20,30,50,100,150,200]
scaling_factor_params = [1,3,0.1]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])
n_I_type_params = len(I_type)
n_lookback_params = len(lookback_params)
n_scaling_factor_params = ((scaling_factor_params[1]-scaling_factor_params[0])/scaling_factor_params[2])
print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('number of I_type params:-',(n_I_type_params))
print('number of lookback params:-',(n_lookback_params))
print('number of scaling_factor params:-',(n_scaling_factor_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params*n_I_type_params*n_lookback_params*n_scaling_factor_params))


# Adjust these parameter according to search space
n_trials = 50 #NGEN
npop = 100
early_stopping_gen = n_trials # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters2 = [grid_params,lot_params,I_type,lookback_params,scaling_factor_params]

results2 = walk_forward_analysis('jan 2018','jan 2023',1,parameters2,optimization_function=deap_optimiser_indicator_std,optimizer_params=optimizer_param,lookback_in_months=3,evaluation_period=1)
results2

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]
I_type = ['v','a']
lookback_params = [9,20,30,50,100,150,200]
scaling_factor_params = [1,3,0.1]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])
n_I_type_params = len(I_type)
n_lookback_params = len(lookback_params)
n_scaling_factor_params = ((scaling_factor_params[1]-scaling_factor_params[0])/scaling_factor_params[2])
print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('number of I_type params:-',(n_I_type_params))
print('number of lookback params:-',(n_lookback_params))
print('number of scaling_factor params:-',(n_scaling_factor_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params*n_I_type_params*n_lookback_params*n_scaling_factor_params))


# Adjust these parameter according to search space
n_trials = 50 #NGEN
npop = 100
early_stopping_gen = n_trials # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters2 = [grid_params,lot_params,I_type,lookback_params,scaling_factor_params]

results3 = walk_forward_analysis('jan 2018','jan 2023',1,parameters2,optimization_function=deap_optimiser_indicator_std,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
results3

# %% [markdown]
# # Rollover (Re-initialising for group 3)

# %%
def deap_optimiser_indicator_rollover(train_start,train_end, test_start,test_end, parameters, optimization_params, position_turnover=1):
    train_pairs = get_date_pairs_(train_start, train_end, interval = position_turnover)
    test_pairs = get_date_pairs_(test_start, test_end, interval = position_turnover)
    
    
    ngen = optimization_params[0]  # number of generations
    npop = optimization_params[1]  # number of population

    error_check(parameters,5)
    
    grid_params = parameters[0]
    position_params = parameters[1]
    indicator_type_params = parameters[2]
    lookback_params = parameters[3]
    scaling_factor_params = parameters[4]

    creator.create("FitnessMax", base.Fitness, weights=(1.0,)) #maximizing
    creator.create("Individual", list, fitness=creator.FitnessMax)

    toolbox = base.Toolbox()

    # Define the genes for our individual
    toolbox.register("G_gene", random.randint, grid_params[0]//grid_params[2], grid_params[1]//grid_params[2])
    toolbox.register("n_gene", random.randint, position_params[0]//position_params[2], position_params[1]//position_params[2])
    toolbox.register("indicator_gene", random.choice, indicator_type_params)
    toolbox.register("lookback_gene", random.choice, lookback_params)
    toolbox.register("scaling_gene", random.randint, scaling_factor_params[0]//scaling_factor_params[2], scaling_factor_params[1]//scaling_factor_params[2])

    CXPB, MUTPB = 0.5, 0.2

    def custom_mutate(individual): 
        if random.random() < MUTPB:
            individual[0] = random.randint(grid_params[0]//grid_params[2], grid_params[1]//grid_params[2])
        if random.random() < MUTPB:
            individual[1] = random.randint(position_params[0]//position_params[2], position_params[1]//position_params[2])
        if random.random() < MUTPB:
           individual[2] = random.choice(indicator_type_params)
        if random.random() < MUTPB:
            individual[3] = random.choice(lookback_params)
        if random.random() < MUTPB:
            individual[4] = random.randint(scaling_factor_params[0]//scaling_factor_params[2], scaling_factor_params[1]//scaling_factor_params[2])

        return individual,

    toolbox.register("mutate", custom_mutate)

    # Create an individual with the genes
    toolbox.register("individual", tools.initCycle, creator.Individual, (toolbox.G_gene, toolbox.n_gene, toolbox.indicator_gene, toolbox.lookback_gene, toolbox.scaling_gene), n=1)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    def objective(individual):
        G, n, indicator_type, lookback, scaling_factor = individual[0]*grid_params[2], individual[1]*position_params[2], individual[2], individual[3], individual[4]*scaling_factor_params[2]
        profit = 0
        for pair in train_pairs:
            train_data = data_gather_from_files(pair[0],pair[1])['EURUSD.mid']
            max_loss, R_PNL, month_profit, _ = run_strategy_optimised(train_data, G, n, indicator_type = indicator_type, lookback = lookback, indicator_scale = scaling_factor)
            constraints = [
                max_loss < -500e3
            ]
            if any(constraints):
                profit += -np.inf # Return large negative value when constraints are not satisfied
            else:
                profit += month_profit
        return profit,    

    toolbox.register("mate", tools.cxTwoPoint)
    toolbox.register("select", tools.selTournament, tournsize=3)   
    toolbox.register("evaluate", objective)

    population = toolbox.population(n=npop)

    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit

    #initiate early stopping
    stagnant_generations = 0  # Counter for generations without improvement
    MAX_STAGNANT_GEN = optimization_params[2]  # Early stopping criterion: stop if no improvement over x generations
    best_fitness_so_far = float('-inf')  # since we're maximizing
    ##
    for gen in range(ngen):
        offspring = toolbox.select(population, len(population))
        offspring = list(map(toolbox.clone, offspring))
        
        # Crossover
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CXPB:
                toolbox.mate(child1, child2)
                del child1.fitness.values
                del child2.fitness.values
        
        # Mutation
        for mutant in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        fitnesses = list(map(toolbox.evaluate, offspring))
        for ind, fit in zip(offspring, fitnesses):
            ind.fitness.values = fit

        #early stopping
        current_best_fitness = max(ind.fitness.values[0] for ind in population)

        if current_best_fitness > best_fitness_so_far:
            best_fitness_so_far = current_best_fitness
            stagnant_generations = 0  # Reset counter
        else:
            stagnant_generations += 1

        if stagnant_generations >= MAX_STAGNANT_GEN:
            print(f"Early stopping on generation {gen} due to no improvement.")
            break
        ##
        population[:] = offspring

    best_ind = tools.selBest(population, 1)[0]
    optimal_g = np.round(best_ind[0]*grid_params[2],5)
    optimal_n = best_ind[1]*position_params[2]
    optimal_type = best_ind[2]
    optimal_l = best_ind[3]
    optimal_scaling = np.round(best_ind[4] *scaling_factor_params[2],5)

    train_df = {}
    test_df = {}
    
    for pair in train_pairs:
        tick_data = data_gather_from_files(pair[0],pair[1])['EURUSD.mid']
        max_loss, R_PNL,profit, _ = run_strategy_optimised(tick_data, optimal_g, optimal_n, indicator_type = optimal_type, lookback = optimal_l, indicator_scale = optimal_scaling)
        train_df[pair[0] +'-'+ pair[1]] = [max_loss, R_PNL,profit,optimal_g,optimal_n,optimal_type,optimal_l,optimal_scaling]
    print("optimisation completed")

    for pair in test_pairs:
        tick_data = data_gather_from_files(pair[0],pair[1])['EURUSD.mid']
        max_loss, R_PNL,profit, _ = run_strategy_optimised(tick_data, optimal_g, optimal_n, indicator_type = optimal_type, lookback = optimal_l, indicator_scale = optimal_scaling)
        test_df[pair[0] +'-'+ pair[1]] = [max_loss, R_PNL,profit,optimal_g,optimal_n,optimal_type,optimal_l,optimal_scaling]
    
    train_df = pd.DataFrame(train_df).T
    train_df.columns = ['max_loss', 'R_PNL','profit','optimal_g','optimal_n','optimal_type','optimal_l','optimal_scaling']
    
    test_df = pd.DataFrame(test_df).T
    test_df.columns = ['max_loss', 'R_PNL','profit','optimal_g','optimal_n','optimal_type','optimal_l','optimal_scaling']
    
    return [optimal_g,optimal_n,optimal_type,optimal_l,optimal_scaling],train_df,test_df

# %%
grid_params = [0.001,0.01,0.0005]
lot_params = [100000,2000000,100000]
I_type = ['v','a']
lookback_params = [9,20,30,50,100,150,200]
scaling_factor_params = [1,3,0.1]

n_grid_params = ((grid_params[1]-grid_params[0])/grid_params[2])
n_lot_params = ((lot_params[1]-lot_params[0])/lot_params[2])
n_I_type_params = len(I_type)
n_lookback_params = len(lookback_params)
n_scaling_factor_params = ((scaling_factor_params[1]-scaling_factor_params[0])/scaling_factor_params[2])
print('number of grid params:-',(n_grid_params))
print('number of lot params:-',(n_lot_params))
print('number of I_type params:-',(n_I_type_params))
print('number of lookback params:-',(n_lookback_params))
print('number of scaling_factor params:-',(n_scaling_factor_params))
print('total_number_of_combinations:-',(n_grid_params*n_lot_params*n_I_type_params*n_lookback_params*n_scaling_factor_params))


# Adjust these parameter according to search space
n_trials = 50 #NGEN
npop = 100
early_stopping_gen = n_trials # no early stopping
optimizer_param = [n_trials, npop, early_stopping_gen]

parameters2 = [grid_params,lot_params,I_type,lookback_params,scaling_factor_params]

results5 = walk_forward_analysis_rollover('jan 2018','jan 2023',1,parameters2,optimization_function=deap_optimiser_indicator_rollover,optimizer_params=optimizer_param,lookback_in_months=12,evaluation_period=1)
results5
# Out:
# number of grid params:- 18.0
# number of lot params:- 19.0
# number of I_type params:- 2
# number of lookback params:- 7
# number of scaling_factor params:- 20.0
# total_number_of_combinations:- 95760.0
# Data gathered for testing period:  01 Jan 2018 31 Jan 2018
# optimisation completed
# Optimal parameters are:  [0.006, 2000000, 'v', 9, 2.4]
# Max loss,profit are:  -109200.0 -35780.0
# Data gathered for testing period:  01 Feb 2018 28 Feb 2018
